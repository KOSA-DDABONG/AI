# %% [markdown]
# # New LangGraph 8/20
# - db search를 3단계로 나눠서 검색
# - LangGraph 구현을 위한 코드
#  - 변경점
#     - 그래프를 고도화시켜서 한번에 db_search를 수행하는 것이 아닌 분기를 두고 수행하도록 변경
#     - keyword 추출에 gpt-4o-mini
#     - scheduler 생성에 gpt-4-turbo

# %% [markdown]
# ## Import Packages

# %%
from typing import TypedDict, Annotated, Optional, List, Dict
import operator
import ast
import pandas as pd
import os
import json
from dotenv import load_dotenv
import pymysql
from sqlalchemy import create_engine

from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_openai import ChatOpenAI
from langchain.schema.runnable import RunnablePassthrough, RunnableMap
from langchain.memory import ConversationSummaryBufferMemory
from IPython.display import Image, display
from langgraph.graph import END, StateGraph
from langgraph.checkpoint.memory import MemorySaver
import pprint
from langgraph.errors import GraphRecursionError
from langchain_core.runnables import RunnableConfig

# %% [markdown]
# ## Define State

# %%
class LangState(TypedDict):
    model: Optional[ChatOpenAI]
    question: Optional[str]
    keywords: Optional[dict]
    foods_context: Annotated[Optional[list], operator.add]
    playing_context: Annotated[Optional[list], operator.add]
    hotel_context: Annotated[Optional[list], operator.add]
    scheduler: Optional[str]#Optional[Dict]
    explain: Optional[str]
    second_sentence: str
    api_key: Optional[str]

# %% [markdown]
# ## Define Function

# %%
def get_db(kind):
    # 환경 변수에서 데이터베이스 정보 가져오기
    db_host = os.getenv("DB_HOST")
    db_port = int(os.getenv("DB_PORT", 3306))
    db_user = os.getenv("DB_USER")
    db_password = os.getenv("DB_PASSWORD")
    db_name = os.getenv("DB_NAME")

    # SQLAlchemy 엔진 생성
    engine = create_engine(f'mysql+pymysql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}')

    if kind == "food":
        sql = """
                SELECT placename, latitude, longitude, teenager, twenties, thirties, fourties, fifties, sixties, 
                       foodtype, bar, parking, operatinghours0, operatinghours1, operatinghours2, operatinghours3, operatinghours4, operatinghours5
                FROM PLACE P JOIN RESTAURANT R ON P.placeid = R.placeid
              """
        # SQL 쿼리를 실행하고 결과를 데이터프레임으로 로드
        df = pd.read_sql(sql, engine)
        return df
    elif kind == "hotel":
        sql = """
                SELECT placename, latitude, longitude, teenager, twenties, thirties, fourties, fifties, sixties, 
                       parking, hoteltype
                FROM PLACE P JOIN HOTEL R ON P.placeid = R.placeid
              """
        # SQL 쿼리를 실행하고 결과를 데이터프레임으로 로드
        df = pd.read_sql(sql, engine)
        return df
    elif kind == "place":
        sql = """
                SELECT placename, latitude, longitude, teenager, twenties, thirties, fourties, fifties, sixties, 
                       single, couple, parents, family, friends, experience, park, uniquetravel, nature, 
                       culture, festival, shopping, history, walking, city, etc, ocean, mountain
                FROM PLACE P JOIN TOUR R ON P.placeid = R.placeid
              """
        df = pd.read_sql(sql, engine)
        return df
    return df

# %%
def update_scheduler(state: LangState, new_scheduler: dict) -> LangState:
    if state['scheduler'] is None:
        state['scheduler'] = new_scheduler
    else:
        # 새로운 값을 기존 scheduler dict에 병합
        state['scheduler'].update(new_scheduler)
    return state

# %%
# 분기 체크 코드
def is_do_again(state: LangState) -> LangState:
    # 끝났는지 검사
    return state['second_sentence']

# %%
# 사용자 DB를 조회해서 연령대를 결정하는 함수
def get_age_group(age):
    if age < 20:
        return 'teenager'
    elif age < 30:
        return 'twenties'
    elif age < 40:
        return 'thirties'
    elif age < 50:
        return 'fourties'
    elif age < 60:
        return 'fifties'
    else:
        return 'sixties'

# %% [markdown]
# ## Define Nodes

# %%
def input_text(state: LangState) -> LangState:

    question = state['question']
    model = ChatOpenAI(temperature=0.3, model="gpt-4o-mini")
    return LangState(question=question, model=model)

def find_keywords(state: LangState) -> LangState:
    
    # 질문과 키워드 기초 상태 받아오기
    question = state['question']
    keywords = {
        'days': None,
        'transport': None,
        'companion': None,
        'theme': None,
        'food': None
    }

    while any(value is None for value in keywords.values()):  # 모든 키워드가 채워질 때까지 반복
        # GPT에게 현재 입력된 정보로부터 키워드 추출 요청
        prompt = ChatPromptTemplate.from_messages([
            ("system", """
        You need to extract the most relevant information from the user's sentence in the context of a trip. 
        The user may provide information about the following categories:
        1. How many days they want to travel (days).
        2. What transportation they have (transport).
        3. Who they are traveling with (companion).
        4. What theme they prefer for the trip (theme).
        5. What type of food they prefer (food).

        Basically, you find keywords from user's input, but you can also recommend keyword as possible as you can.
        For example
        - if the input is '쉬러 가고 싶어' means '휴식' so you can recommend '바다' or '자연' or '공원'
        - if the input is '라면먹고 싶어' means wanna eat '라면' so you can recommend '한식' or '일식'
        - if the input is '사람들을 만나러 가고싶어' means wanna hang with people, so you can recommend '도시' or '체험' or '쇼핑'
        - if the input is '아무거나' or '상관없어' or '아무데나' means everywhere and everything, so you can recommend randomly from format.
        - if the input is '나머지는 추천해줘' or '나머지는 알아서 해줘' means recommend the rest of categories, so you can recommend from format for the rest of categories.
        
        Following Rules:
        - if you are short of information from user's sentence, but user just want recommend of rest, then you can recommend from format.
        - Recommending is your option, but you just return one keyword at one category.

        days
        - just return Number of days. liks 'N'. just integer.

        transport
        - if user have a car, or rent a car means '자차', but if user use taxi, bus, airplane, or other things not a car, then '대중교통'

        response
        - When the number of categories provided from the user's input is insufficient, a message providing additional information may be transmitted to the user as response.
        - Your reaction is as natural like to respond appropriately to the other person's sentence as you're having a real conversation, and at the same time, you ask questions to receive categories that you lack.
        - if you get all categories, then just return 'End' at response.

        user input: "{question}, {keywords}"

        Return the information in the following format:
        {{
            'days': 'Number of days' or None,
            'transport': '자차/대중교통' or None,
            'companion': '가족/부모/친구/연인/혼자' or None,
            'theme': '자연/걷기/쇼핑/공원/이색여행/문화/체험/역사/산/바다/도시' or None,
            'food': '한식/양식/중식/일식/아시아' or None,
            'response': 'response'
        }}
        """),
        ("human","{question}, {keywords}")
        ])

        chain = prompt | state['model']
        response = chain.invoke({"question": question, "keywords": keywords})
        extracted_keywords = ast.literal_eval(response.content)

        # 이미 대답된 정보를 저장
        for key, value in extracted_keywords.items():
            if key in keywords and value is not None and key != 'response':
                if keywords[key] is None: keywords[key] = value
        
        # 모든 키워드가 채워졌는지 확인하여 루프 종료
        if all(value is not None for value in keywords.values()):
            break

        # Check if the response suggests asking for more relevant travel information
        if 'response' in extracted_keywords and extracted_keywords['response'] != 'End':
            print(extracted_keywords['response'])
            question = input(": ").strip()
            continue  # Re-run the loop to process the new input
    
    return LangState(keywords=keywords)

def foods_search(state: LangState) -> LangState:

    #user 나이 반환 미구현
    user_age = 29
    data = get_db('food')

    keywords = state['keywords']
    k = int(state['keywords']['days'])
    
    def recommend_restaurants(data, condition, user_age, k):
        # 연령대 설정
        if condition['companion'] == '부모':
            user_age_group = 'sixties'
        else:
            user_age_group = get_age_group(user_age)
        
        # Companion 및 술집 필터링
        if condition['companion'] in ['가족', '부모']:
            data = data[data['bar'] == 0]
        
        # Time-based Filtering
        def filter_by_time(time_slot):
            if time_slot == '아침':
                return data[(data['operatinghours0'] == 1) | (data['operatinghours1'] == 1) | (data['operatinghours2'] == 1)]
            elif time_slot == '점심':
                return data[(data['operatinghours2'] == 1) | (data['operatinghours3'] == 1)]
            elif time_slot == '저녁':
                return data[(data['operatinghours4'] == 1) | (data['operatinghours5'] == 1)]
        
        # 가중치 계산
        def calculate_weights(row):
            # Food 가중치
            food_weight = 0.43 if row['foodtype'] == condition['food'] else 0.28
        
            # 연령대 가중치
            age_score = row[user_age_group]
            
            # 최종 점수 계산
            return food_weight * age_score
        
        # 아침, 점심, 저녁 별로 추천 4k개만큼
        recommendations = {}
        recommended_restaurants = set()
        for time_slot in ['아침', '점심', '저녁']:
            filtered_data = filter_by_time(time_slot).copy()  # 명시적으로 복사본을 생성
            filtered_data['FinalScore'] = filtered_data.apply(calculate_weights, axis=1)
            top_restaurants = filtered_data[~filtered_data['placename'].isin(recommended_restaurants)] \
                .sort_values(by='FinalScore', ascending=False).head(k*4)
            
            recommendations[time_slot] = list(zip(top_restaurants['placename'], top_restaurants['latitude'], top_restaurants['longitude']))
            
            # 이미 추천된 식당을 추적하여 다음 시간대에 제외
            recommended_restaurants.update(top_restaurants['placename'])
        
        return recommendations

    response = recommend_restaurants(data, keywords, user_age, k)

    return LangState(foods_context=response)

def hotels_search(state: LangState) -> LangState:

    #나이 반환 미구현
    user_age = 29
    data = get_db('hotel')

    keywords = state['keywords']
    k = int(state['keywords']['days'])

    def recommend_accommodation_with_keywords(data, condition, user_age, k):
        # 연령대 설정
        if condition['companion'] == '부모':
            user_age_group = 'sixties'
        else:
            user_age_group = get_age_group(user_age)
        
        # 숙박 유형 가중치 설정
        accommodation_weight = {
        '가족': {'호텔': 0.3, '모텔': 0.1, '펜션': 0.6, '게스트하우스': 0},
        '부모': {'호텔': 0.48, '모텔': 0.125, '펜션': 0.395, '게스트하우스': 0},
        '친구': {'호텔': 0.265, '모텔': 0.205, '펜션': 0.26, '게스트하우스': 0.27},
        '연인': {'호텔': 0.27, '모텔': 0.37, '펜션': 0.27, '게스트하우스': 0.09},
        '혼자': {'호텔': 0.263, '모텔': 0.264, '펜션': 0, '게스트하우스': 0.473},
        }
        
        # 필터링
        filtered_data = data.copy()
        
        # 교통수단에 따른 주차 필터링
        if condition['transport'] == '자차':
            filtered_data = filtered_data[filtered_data['parking'] == 'Y']
        
        # 숙박 유형 점수 계산
        filtered_data['typescore'] = filtered_data['hoteltype'].apply(lambda x: accommodation_weight[condition['companion']].get(x, 0))
        
        # 연령대 점수 계산
        filtered_data['age_like'] = filtered_data[user_age_group]
        
        # 총점 계산
        filtered_data['FinalScore'] = filtered_data['typescore'] * filtered_data['age_like']
        
        # 총점 기준으로 상위 3k개 숙박지 추천
        recommended = filtered_data.sort_values(by='FinalScore', ascending=False).head(k*3)

        # 이름, 위도, 경도 리스트로 반환
        result = list(zip(recommended['placename'], recommended['latitude'], recommended['longitude']))
        return result
        
    response = recommend_accommodation_with_keywords(data, keywords, user_age, k)

    return LangState(hotel_context=response)

def places_search(state: LangState) -> LangState:
    
    #data 조회함수 -> hotels.csv 및 user의 나이까지 반환해야함.
    user_age = 29
    data = get_db('place')

    keywords = state['keywords']
    k = int(state['keywords']['days'])

    def recommend_travel_destinations(data, condition, user_age, k):
        # 연령대 설정
        if condition['companion'] == '부모':
            user_age_group = 'sixties'
        else:
            user_age_group = get_age_group(user_age)
        
        # Companion 가중치 계산
        if condition['companion'] == '가족':
            comp = 'family'
        elif condition['companion'] == '부모':
            comp = 'parents'
        elif condition['companion'] == '친구':
            comp = 'friends'
        elif condition['companion'] == '연인':
            comp = 'couple'
        elif condition['companion'] == '혼자':
            comp = 'single'
        data['CompanionWeight'] = data[comp].apply(lambda x: 0.6 if x == 1 else 0.1)

        # Theme 그룹 설정
        theme_groups = {
            'nature': ['mountain', 'ocean', 'park', 'walking', 'etc'],
            'city': ['shopping', 'festival', 'culture', 'etc'],
            'history': ['uniquetravel', 'walking', 'culture', 'etc'],
            'uniquetravel': ['experience', 'walking', 'culture', 'park', 'etc'],
            'ocean': ['ocean', 'nature', 'etc'],
            'mountain': ['walking', 'nature', 'etc'],
            'culture': ['festival', 'city', 'etc'],
            'experience': ['uniquetravel', 'walking', 'culture', 'etc'],
            'park': ['nature', 'city', 'etc'],
            'shopping': ['ocean', 'city', 'festival', 'etc'],
            'festival': ['culture', 'shopping', 'etc'],
            'walking': ['uniquetravel', 'mountain', 'park', 'nature', 'culture', 'history', 'city'],
            'etc': ['nature', 'walking', 'park', 'shopping', 'uniquetravel', 'culture', 'festival', 'experience', 'history', 'mountain', 'ocean', 'city']
        }
        
        # 한글 테마를 영어로 치환하기 위한 매핑 사전
        theme_mapping = {
            '자연': 'nature',
            '도시': 'city',
            '역사': 'history',
            '이색여행': 'uniquetravel',
            '바다': 'ocean',
            '산': 'mountain',
            '문화': 'culture',
            '체험': 'experience',
            '공원': 'park',
            '쇼핑': 'shopping',
            '축제': 'festival',
            '걷기': 'walking',
            '기타': 'etc'
        }

        # condition['theme']가 단일 값일 때
        main_theme = theme_mapping.get(condition['theme'], 'etc')
        related_themes = theme_groups.get(main_theme, [])
        
        # Theme 가중치 계산
        def calculate_theme_weight(row):
            if row[main_theme] == 1:
                return 0.5
            elif any(row[theme] == 1 for theme in related_themes):
                return 0.35
            else:
                return 0.15
        
        data['ThemeWeight'] = data.apply(calculate_theme_weight, axis=1)
        
        # 연령대 점수와 가중치 곱셈
        data['FinalScore'] = data[user_age_group] * data['CompanionWeight'] * data['ThemeWeight']
        
        # 최종 점수 기준 상위 12K개 여행지 추천
        recommended = data.sort_values(by='FinalScore', ascending=False).head(k*12)
        
        # 이름, 위도, 경도 리스트로 반환
        result = list(zip(recommended['placename'], recommended['latitude'], recommended['longitude']))

        # 이름과 상세설명만 반환
        return result
    
    response = recommend_travel_destinations(data, keywords, user_age, k)

    return LangState(playing_context=response)

def make_schedule(state: LangState) -> LangState:
    model = ChatOpenAI(temperature=0.3, model="gpt-4-turbo")
    prompt = ChatPromptTemplate.from_messages([
    ("system", """
    Your task is to generate a travel itinerary based on the provided data and specific requirements. The output should include both the reasoning behind the itinerary and a daily schedule in JSON format.

    ====
    def generate_itinerary(hotels: list, tourist_spots: list, restaurants: dict, days: int) -> dict:
        Generates a travel itinerary for 'n' days using the provided data. The itinerary should be returned in JSON format and follow these guidelines:

        - Each day's itinerary must include breakfast, lunch, and dinner. Breakfast and lunch should be at different restaurants, while dinner can also be at a restaurant or bar.
        - Each day should include visits to 2 different tourist spots, with a balanced mix of activities (e.g., cultural, natural, historical).
        - A different hotel should be assigned each night, with a maximum of 3 consecutive nights at the same hotel to ensure variety.
        - The itinerary should start at a central location on the first day and end at the same location on the last day (e.g., a train station), but this location is not considered a tourist spot.
        - The itinerary should be unique and slightly different each time it is generated, with random selections of restaurants, tourist spots, and hotels to provide a varied experience.
        - The JSON output should use the day number as the key and include the itinerary for that day as the value.
        - The last day should not include a hotel stay.
        - Provide a detailed explanation of why the itinerary was planned in this way, considering factors such as travel convenience, variety, user preferences, and the optimal use of time.

        Args:
            hotels (list): A list of tuples, where each tuple contains the hotel name, latitude, and longitude (e.g., [(name, latitude, longitude), ...]).
            tourist_spots (list): A list of tuples, where each tuple contains the tourist spot name, latitude, and longitude (e.g., [(name, latitude, longitude), ...]).
            restaurants (dict): A dictionary with keys '아침', '점심', '저녁', and values are lists of tuples containing the restaurant name, latitude, and longitude (e.g., {{'아침': [(name, latitude, longitude), ...], '점심': [...], '저녁': [...]}}).
            days (int): The number of days for the itinerary.

        Returns:
            dict: A dictionary with two keys:
                1. "reasoning": A detailed explanation of the rationale behind the itinerary to korean.
                2. "itinerary": A JSON-formatted dictionary representing the travel itinerary. Each day's itinerary should include locations for breakfast, lunch, dinner, and two tourist spots, along with their respective names and coordinates.

    # Example usage
    result = generate_itinerary(hotels, tourist_spots, restaurants, days)
    return result

    ====
    # Response format
    generate_itinerary({hotels}, {tourist_spots}, {restaurants}, {days})
    ====
    """),
        ("human","{hotels}, {tourist_spots}, {restaurants}, {days}")
    ])

    chain = prompt | model

    # 올바른 변수명을 사용하여 chain을 실행합니다.
    result = chain.invoke({
        "hotels": state['hotel_context'], 
        "tourist_spots": state['playing_context'], 
        "restaurants": state['foods_context'], 
        "days": int(state['keywords']['days'])  # days는 int로 변환
    })

    schedule = result.content

    # 파싱 전, 중간의 ```json```과 ```를 제거합니다.
    json_start = schedule.find('{')
    json_end = schedule.rfind('}')
    json_data_str = schedule[json_start:json_end+1]

    # JSON을 파싱합니다.
    itinerary_data = json.loads(json_data_str)

    # 메시지 추출: JSON 파싱 전의 텍스트를 추출하여 메시지로 저장합니다.
    message_start = schedule.find("Based on the provided data")
    message_end = json_start
    message = schedule[message_start:message_end].strip()
    
    
    schedule = json.dumps(itinerary_data['itinerary'], indent=4, ensure_ascii=False)
    
    return LangState(scheduler = schedule, explain=message, model=model)

def validation(state: LangState) -> LangState:

    model = ChatOpenAI(temperature=0.3, model="gpt-4o-mini")
    
    prompt = ChatPromptTemplate.from_messages([
        ("system", """
        Your task is to classify the sentence into one of the following categories: ["Other", "Again", "Good"]
        ====
        def classify(sentence: str) -> Literal["Other", "Again", "Good"]:
            Classify the sentence into one of the following categories based on the user's intent:

            - Again: The user wants to start over or re-enter information. Examples include phrases like '처음부터 할래' or '다시 입력하게 해줘'.
            - Other: The user wants to search again or is unsatisfied with the current result. Examples include phrases like '다시 찾아줘' or '여기 별로야'.
            - Good: The user is satisfied or wants to move forward. Examples include phrases like '알겠어' or '좋아'.
            
            Args:
                sentence (str): The sentence that needs to be classified.
            
            Returns:
                Literal["Other", "Again", "Good"]: The classification of the sentence.
        ====
        # Get result
        result = classify_sentence(sentence)
        return result

        ====
        # Response format
        classify("{human}")
        """),
    ("human", "{human}")
    ])
    chain = prompt | model
    answer = chain.invoke({"human": input("어때요?")})
    answer = answer.content

    return LangState(second_sentence=answer, model=model)

# %% [markdown]
# ## Link Nodes

# %%
# get StateGraph & END from langgraph.graph
workflow = StateGraph(LangState)

# Add Nodes
workflow.add_node('input', input_text)
workflow.add_node('keyword', find_keywords)
workflow.add_node('hotels', hotels_search)
workflow.add_node('restaurants', foods_search)
workflow.add_node('playing', places_search)
workflow.add_node('scheduling', make_schedule)
workflow.add_node('validating', validation)

# Link Nodes
workflow.add_edge('input', 'keyword')
workflow.add_edge('keyword', 'hotels')
workflow.add_edge('keyword', 'restaurants')
workflow.add_edge('keyword', 'playing')
workflow.add_edge('hotels', 'scheduling')
workflow.add_edge('restaurants', 'scheduling')
workflow.add_edge('playing', 'scheduling')
workflow.add_edge('scheduling', 'validating')

# Add Conditional Edges
workflow.add_conditional_edges(
    "validating",
    is_do_again,
    {
        "Good" : END,
        "Other": 'scheduling',
        "Again": 'input',
    },
)

# Set Start Point
workflow.set_entry_point('input')

# Set Memory for Log
memory = MemorySaver()

# Compile Graph
app = workflow.compile(checkpointer=memory)

# %%
config = RunnableConfig(
    recursion_limit=15, configurable={"thread_id": "TRIPFLOW-RAG"}
)

# %% [markdown]
# ## Draw Graph

# %%
try:
    display(
        Image(app.get_graph(xray=True).draw_mermaid_png())
    )
except Exception as e:
    print(f"Error: {e}")

# %% [markdown]
# ## Main

# %%
def running(LangState, model):
    inputs = LangState(model=model)
    # app.stream을 통해 입력된 메시지에 대한 출력을 스트리밍합니다.
    try:
        for output in app.stream(inputs, config=config):
            # 출력된 결과에서 키와 값을 순회합니다.
            for key, value in output.items():
                # 노드의 이름과 해당 노드에서 나온 출력을 출력합니다.
                pprint.pprint(f"Output from node '{key}':")
                pprint.pprint("---")
                # 출력 값을 예쁘게 출력합니다.
                pprint.pprint(value, indent=2, width=80, depth=None)
            # 각 출력 사이에 구분선을 추가합니다.
            pprint.pprint("\n---\n")
    except GraphRecursionError as e:
        pprint.pprint(f"Recursion limit reached: {e}")

# %%
def running(LangState, i):
    inputs = LangState(question=i)
    results = {}  # 결과를 저장할 빈 사전 생성

    try:
        for output in app.stream(inputs, config=config):
            for key, value in output.items():
                # 결과를 사전에 저장
                results[key] = value

                # 필요 시 출력 (이 부분은 나중에 제거하거나 조정할 수 있습니다)
                pprint.pprint(f"Output from node '{key}':")
                pprint.pprint("---")
                pprint.pprint(value, indent=2, width=80, depth=None)
            pprint.pprint("\n---\n")
    except GraphRecursionError as e:
        pprint.pprint(f"Recursion limit reached: {e}")

    return results  # 저장된 결과 반환

# %%
# 시작변수들 설정
m = ChatOpenAI(temperature=0.3, model="gpt-4o-mini")

# %%
i = "나는 부산 여행을 가고 싶어"
sultsult = running(LangState, i)
# Out:
# "Output from node 'input':"
# '---'
# { 'model': ChatOpenAI(client=<openai.resources.chat.completions.Completions object at 0x7fb740dff760>, async_client=<openai.resources.chat.completions.AsyncCompletions object at 0x7fb740e198a0>, model_name='gpt-4o-mini', temperature=0.3, openai_api_key=SecretStr('**********'), openai_proxy=''),
#   'question': '나는 부산 여행을 가고 싶어'}
# '\n---\n'
# 부산은 바다와 관련된 여행이 좋을 것 같아요. 여행 기간은 며칠 계획하고 계신가요? 그리고 어떤 교통수단을 이용하실 건가요?
# 여행 기간과 교통수단, 동행자에 대한 정보를 더 알려주실 수 있나요? 그리고 어떤 음식을 선호하시는지도 궁금해요.
# 음식에 대한 선호가 없으시네요. 어떤 음식을 좋아하시나요?
# "Output from node 'keyword':"
# '---'
# { 'keywords': { 'companion': '혼자',
#                 'days': '1',
#                 'food': '해산물',
#                 'theme': '바다',
#                 'transport': '대중교통'}}
# '\n---\n'
# "Output from node 'playing':"
# '---'
# { 'playing_context': [ ('대항어촌마을', 35.0117, 128.825),
#                        ('수영강상설카약체험장', 35.1699, 129.123),
#                        ('사라수변공원', 35.2382, 129.205),
#                        ('동백방파제', 35.2882, 129.255),
#                        ('일광해수욕장', 35.26, 129.234),
#                        ('천마산전망대', 35.0892, 129.015),
#                        ('병산저수지', 35.3437, 129.173),
#                        ('삼포해안길', 35.16, 129.171),
#                        ('광안리해수욕장', 35.1532, 129.119),
#                        ('몰운대 몽돌해변', 35.1323, 129.051),
#                        ('송정해수욕장', 35.1786, 129.199),
#                        ('청사포', 35.1602, 129.191)]}
# '\n---\n'
# "Output from node 'restaurants':"
# '---'
# { 'foods_context': { '아침': [ ('1865이탈리아', 35.1756, 129.126),
#                              ('가얏골감자탕 부산지사점', 35.1503, 128.834),
#                              ('가빈초장', 35.2437, 129.215),
#                              ('가온밀면 사직점', 35.2018, 129.065)],
#                      '저녁': [ ('83해치', 35.158, 129.061),
#                              ('102족발보쌈', 35.1394, 128.988),
#                              ('가마솥통닭꾸러기', 35.2378, 129.212),
#                              ('가배참치', 35.253, 129.217)],
#                      '점심': [ ('E조은참치', 35.106, 129.037),
#                              ('1986옛날돈까스', 35.2379, 129.085),
#                              ('라이프버거', 35.1019, 129.036),
#                              ('가복밀면', 35.1844, 129.126)]}}
# '\n---\n'
# "Output from node 'hotels':"
# '---'
# { 'hotel_context': [ ('다니엘게스트하우스', 35.1514, 129.061),
#                      ('태림하우스', 35.114, 129.037),
#                      ('단디게스트하우스', 35.1041, 129.035)]}
# '\n---\n'
# "Output from node 'scheduling':"
# '---'
# { 'explain': '',
#   'model': ChatOpenAI(client=<openai.resources.chat.completions.Completions object at 0x7fb7212fd2d0>, async_client=<openai.resources.chat.completions.AsyncCompletions object at 0x7fb7212fedd0>, model_name='gpt-4-turbo', temperature=0.3, openai_api_key=SecretStr('**********'), openai_proxy=''),
#   'scheduler': '{\n'
#                '    "Day 1": {\n'
#                '        "Hotel": [\n'
#                '            "다니엘게스트하우스",\n'
#                '            35.1514,\n'
#                '            129.061\n'
#                '        ],\n'
#                '        "Breakfast": [\n'
#                '            "1865이탈리아",\n'
#                '            35.1756,\n'
#                '            129.126\n'
#                '        ],\n'
#                '        "Lunch": [\n'
#                '            "E조은참치",\n'
#                '            35.106,\n'
#                '            129.037\n'
#                '        ],\n'
#                '        "Dinner": [\n'
#                '            "83해치",\n'
#                '            35.158,\n'
#                '            129.061\n'
#                '        ],\n'
#                '        "Tourist Spots": [\n'
#                '            [\n'
#                '                "대항어촌마을",\n'
#                '                35.0117,\n'
#                '                128.825\n'
#                '            ],\n'
#                '            [\n'
#                '                "수영강상설카약체험장",\n'
#                '                35.1699,\n'
#                '                129.123\n'
#                '            ]\n'
#                '        ]\n'
#                '    }\n'
#                '}'}
# '\n---\n'
# "Output from node 'validating':"
# '---'
# { 'model': ChatOpenAI(client=<openai.resources.chat.completions.Completions object at 0x7fb740f29ff0>, async_client=<openai.resources.chat.completions.AsyncCompletions object at 0x7fb740f2b910>, model_name='gpt-4o-mini', temperature=0.3, openai_api_key=SecretStr('**********'), openai_proxy=''),
#   'second_sentence': 'Good'}
# '\n---\n'

# %%
sultsult['scheduling']['scheduler']
# Out:
# '{\n    "Day 1": {\n        "Hotel": [\n            "다니엘게스트하우스",\n            35.1514,\n            129.061\n        ],\n        "Breakfast": [\n            "1865이탈리아",\n            35.1756,\n            129.126\n        ],\n        "Lunch": [\n            "E조은참치",\n            35.106,\n            129.037\n        ],\n        "Dinner": [\n            "83해치",\n            35.158,\n            129.061\n        ],\n        "Tourist Spots": [\n            [\n                "대항어촌마을",\n                35.0117,\n                128.825\n            ],\n            [\n                "수영강상설카약체험장",\n                35.1699,\n                129.123\n            ]\n        ]\n    }\n}'

# %% [markdown]
# ### Remaining Tasks
# - MySQL 접속하는 Code단 구현 안되어있음.
# - user의 나이를 조회하는 코드도 구현해야함.
# - FastAPI 혹은 Flask를 활용해 Spring과 데이터 주고받기 미구현

# %% [markdown]
# ## Flask & DB 연동

# %%
# 환경 변수에서 데이터베이스 정보 가져오기
db_host = os.getenv("DB_HOST")
db_port = int(os.getenv("DB_PORT", 3306))
db_user = os.getenv("DB_USER")
db_password = os.getenv("DB_PASSWORD")
db_name = os.getenv("DB_NAME")

conn = pymysql.connect(
        host=db_host,
        port=db_port,
        user=db_user,
        password=db_password,
        database=db_name
    )

# %%
cur = conn.cursor()

# %%
sql = "SELECT * FROM PLACE P JOIN HOTEL R ON P.PLACEID = R.PLACEID"
cur.execute(sql)
result = cur.fetchall()
for data in result:
    print(data)
# Out:
# (165, '베스티호텔', 35.1282, 128.854, None, 1, '부산광역시', '강서구', '구랑동', 'nan', '1205-2', '미음산단로', '17', 104, 325, 302, 498, 235, 31, 165, 'Y', '호텔')
# (166, '대저캠핑장', 35.2159, 128.991, None, 1, '부산광역시', '강서구', '대저1동', 'nan', '01-05', 'nan', 'nan', 408, 489, 481, 462, 428, 282, 166, 'Y', '모텔')
# (167, '대저생태공원캠핑장', 35.2074, 128.985, None, 1, '부산광역시', '강서구', '대저1동', 'nan', '01-05', 'nan', 'nan', 206, 427, 394, 385, 289, 201, 167, 'N', '모텔')
# (168, '공항하숙', 35.1807, 128.956, None, 1, '부산광역시', '강서구', '대저2동', 'nan', '1843-22', '공항로811번길', '60-20', 189, 86, 136, 208, 402, 251, 168, 'Y', '모텔')
# (169, '에어포트호텔', 35.1657, 128.955, None, 1, '부산광역시', '강서구', '대저2동', 'nan', '17624', '유통단지1로65번길', '15', 359, 441, 394, 453, 365, 47, 169, 'Y', '호텔')
# (170, '초롱블루펜션', 35.0154, 128.834, None, 1, '부산광역시', '강서구', '대항동', 'nan', '01-17', '가덕해안로1169번길', '62-33', 385, 307, 375, 466, 465, 94, 170, 'Y', '펜션')
# (171, '썬앤문풀빌라', 35.0155, 128.834, None, 1, '부산광역시', '강서구', '대항동', 'nan', '03-17', '가덕해안로1169번길', '96', 314, 139, 191, 470, 372, 59, 171, 'N', '펜션')
# (172, '파도소리', 35.0162, 128.835, None, 1, '부산광역시', '강서구', '대항동', 'nan', '09-03', '가덕해안로1169번길', '62-47', 254, 51, 209, 284, 396, 349, 172, 'N', '모텔')
# (173, '하늘과바다', 35.0149, 128.834, None, 1, '부산광역시', '강서구', '대항동', 'nan', '05-23', '가덕해안로1169번길', '80', 285, 178, 229, 354, 318, 51, 173, 'Y', '펜션')
# (174, '썬앤문풀빌라', 35.0154, 128.834, None, 1, '부산광역시', '강서구', '대항동', 'nan', '11-17', '가덕해안로1169번길', '104', 297, 176, 205, 480, 415, 119, 174, 'N', '펜션')
# (175, '가덕도새바지펜션', 35.0147, 128.834, None, 1, '부산광역시', '강서구', '대항동', 'nan', '24', '가덕해안로1169번길', '62-22', 401, 130, 306, 451, 413, 89, 175, 'N', '펜션')
# (176, '대항체험마을민박', 35.0117, 128.828, None, 1, '부산광역시', '강서구', '대항동', 'nan', '245-1', '가덕해안로1207번길', 'nan', 116, 72, 88, 381, 475, 408, 176, 'Y', '모텔')
# (177, '섬마을장어구이펜션', 35.0142, 128.828, None, 1, '부산광역시', '강서구', '대항동', 'nan', '385', '가덕해안로1208번길', '45', 333, 220, 262, 437, 355, 33, 177, 'Y', '펜션')
# (178, '대항펜션', 35.0137, 128.827, None, 1, '부산광역시', '강서구', '대항동', 'nan', '388', '가덕해안로1212번길', '36', 262, 95, 100, 493, 408, 43, 178, 'Y', '펜션')
# (179, '대항민박', 35.0131, 128.828, None, 1, '부산광역시', '강서구', '대항동', 'nan', '274', '가덕해안로1212번길', '20', 271, 196, 230, 418, 449, 430, 179, 'Y', '모텔')
# (180, 'W모텔', 35.1008, 128.929, None, 1, '부산광역시', '강서구', '명지동', 'nan', '1532-12', '르노삼성대로', '598', 137, 374, 224, 165, 138, 121, 180, 'Y', '모텔')
# (181, '비엠텔모텔', 35.0989, 128.928, None, 1, '부산광역시', '강서구', '명지동', 'nan', '1526-14', '르노삼성대로', '576-2', 204, 418, 414, 305, 267, 149, 181, 'Y', '모텔')
# (182, '마틴호텔', 35.1011, 128.929, None, 1, '부산광역시', '강서구', '명지동', 'nan', '1532-11', '르노삼성대로', '600', 130, 277, 260, 452, 166, 36, 182, 'Y', '호텔')
# (183, 'JK호텔', 35.1002, 128.929, None, 1, '부산광역시', '강서구', '명지동', 'nan', '1530-16', '르노삼성대로', '590', 270, 451, 438, 498, 385, 176, 183, 'Y', '호텔')
# (184, '모텔 제타', 35.1039, 128.929, None, 1, '부산광역시', '강서구', '명지동', 'nan', '1279-35', '르노삼성대로', '634', 134, 493, 377, 202, 170, 70, 184, 'Y', '모텔')
# (185, '모텔 마르', 35.1039, 128.929, None, 1, '부산광역시', '강서구', '명지동', 'nan', '1279-3', '르노삼성대로', '634', 68, 433, 378, 284, 176, 57, 185, 'N', '모텔')
# (186, '헤리티지디자인호텔', 35.1004, 128.929, None, 1, '부산광역시', '강서구', '명지동', 'nan', '1530-9', '르노삼성대로', '592', 348, 411, 396, 494, 391, 173, 186, 'Y', '호텔')
# (187, '디자인팝 모텔', 35.0991, 128.928, None, 1, '부산광역시', '강서구', '명지동', 'nan', '1526-13', '르노삼성대로', '576-4', 38, 412, 340, 272, 233, 31, 187, 'Y', '모텔')
# (188, '씨사이드모텔', 35.0983, 128.928, None, 1, '부산광역시', '강서구', '명지동', 'nan', '1502-2', '르노삼성대로', '566', 170, 495, 256, 192, 181, 147, 188, 'Y', '모텔')
# (189, '비엠텔모텔', 35.099, 128.928, None, 1, '부산광역시', '강서구', '명지동', 'nan', '1526-14', '르노삼성대로', '576-2', 317, 398, 353, 333, 329, 219, 189, 'Y', '모텔')
# (190, '브라운도트호텔 명지점', 35.0992, 128.928, None, 1, '부산광역시', '강서구', '명지동', 'nan', '1526-3', '르노삼성대로', '576-6', 229, 489, 370, 497, 324, 140, 190, 'Y', '호텔')
# (191, '넘버25호텔', 35.094, 128.908, None, 1, '부산광역시', '강서구', '명지동', 'nan', '44594', '명지국제2로28번길', '7', 195, 358, 315, 405, 268, 130, 191, 'Y', '호텔')
# (192, '더포인트호텔', 35.0934, 128.908, None, 1, '부산광역시', '강서구', '명지동', 'nan', '44595', '명지국제2로28번길', '8', 260, 350, 267, 362, 264, 234, 192, 'Y', '호텔')
# (193, '호텔오유', 35.0922, 128.902, None, 1, '부산광역시', '강서구', '명지동', 'nan', '32752', '명지국제6로', '21', 174, 338, 334, 467, 252, 136, 193, 'Y', '호텔')
# (194, '오이아호텔명지', 35.0939, 128.9, None, 1, '부산광역시', '강서구', '명지동', 'nan', '29983', '명지국제6로1번길', '24', 92, 435, 348, 484, 278, 31, 194, 'Y', '호텔')
# (195, '씨엘오션호텔', 35.0907, 128.902, None, 1, '부산광역시', '강서구', '명지동', 'nan', '33848', '명지국제6로34번길', '22', 171, 227, 223, 360, 199, 133, 195, 'Y', '호텔')
# (196, '신라스테이', 35.0967, 128.905, None, 1, '부산광역시', '강서구', '명지동', 'nan', '34700', '명지국제7로', '38', 240, 445, 334, 455, 324, 36, 196, 'Y', '호텔')
# (197, '넘버25호텔 명지오션시티점 비즈니스', 35.0805, 128.903, None, 1, '부산광역시', '강서구', '명지동', 'nan', '13667', '명지오션시티3로', '41', 325, 378, 377, 445, 362, 153, 197, 'Y', '호텔')
# (198, '오션시티호텔', 35.0809, 128.903, None, 1, '부산광역시', '강서구', '명지동', 'nan', '13606', '명지오션시티3로', '37', 213, 337, 284, 395, 227, 195, 198, 'Y', '호텔')
# (199, '사이버모텔', 35.0827, 128.904, None, 1, '부산광역시', '강서구', '명지동', 'nan', '14519', '명지오션시티5로', '18', 358, 448, 411, 372, 361, 214, 199, 'Y', '모텔')
# (200, '호텔프렌치코드', 35.0836, 128.904, None, 1, '부산광역시', '강서구', '명지동', 'nan', '3239-15', '명지오션시티5로', '8', 216, 387, 311, 485, 229, 173, 200, 'Y', '호텔')
# (201, '레전드호텔', 35.1596, 128.864, None, 1, '부산광역시', '강서구', '미음동', 'nan', '1527-1', '미음산단5로', '48', 152, 260, 219, 303, 154, 77, 201, 'Y', '호텔')
# (202, '마글램핑장', 35.1536, 128.879, None, 1, '부산광역시', '강서구', '범방동', 'nan', '1833', '가락대로', '929', 262, 486, 467, 420, 365, 99, 202, 'N', '모텔')
# (203, '베스트루이스해밀턴호텔 서부산점', 35.1469, 128.879, None, 1, '부산광역시', '강서구', '범방동', 'nan', '1899-5', '범방3로29번길', '6', 229, 433, 429, 460, 301, 185, 203, 'Y', '호텔')
# (204, '장항펜션', 35.0557, 128.806, None, 1, '부산광역시', '강서구', '성북동', 'nan', '1322', '가덕해안로', '339', 313, 123, 302, 367, 355, 51, 204, 'N', '펜션')
# (205, '성고개산장', 35.1108, 128.853, None, 1, '부산광역시', '강서구', '송정동', 'nan', '103', '신촌소류지길', '15-28', 241, 466, 448, 405, 266, 120, 205, 'Y', '모텔')
# (206, '벨라지오모텔', 35.0866, 128.881, None, 1, '부산광역시', '강서구', '신호동', 'nan', '213-5', '신호산단1로217번길', '7', 157, 458, 386, 290, 228, 70, 206, 'Y', '모텔')
# (207, 'IW모텔', 35.0866, 128.88, None, 1, '부산광역시', '강서구', '신호동', 'nan', '213-1', '신호산단1로217번길', '19', 103, 494, 468, 184, 113, 40, 207, 'Y', '모텔')
# (208, '호텔더메이', 35.0866, 128.879, None, 1, '부산광역시', '강서구', '신호동', 'nan', '216-5', '신호산단1로217번길', '27', 64, 401, 400, 492, 101, 31, 208, 'Y', '호텔')
# (209, '2월호텔', 35.0866, 128.879, None, 1, '부산광역시', '강서구', '신호동', 'nan', '216-3', '신호산단1로217번길', '31', 51, 386, 227, 390, 128, 44, 209, 'Y', '호텔')
# (210, 'S모텔', 35.0866, 128.878, None, 1, '부산광역시', '강서구', '신호동', 'nan', '216', '신호산단1로217번길', '37', 102, 485, 470, 442, 383, 59, 210, 'Y', '모텔')
# (211, '블랑비즈니스호텔', 35.087, 128.881, None, 1, '부산광역시', '강서구', '신호동', 'nan', '214-8', '신호산단1로217번길', '10', 170, 393, 372, 428, 228, 46, 211, 'Y', '호텔')
# (212, '까르페호텔', 35.0866, 128.881, None, 1, '부산광역시', '강서구', '신호동', 'nan', '213-3', '신호산단1로217번길', '15', 107, 446, 318, 449, 141, 48, 212, 'Y', '호텔')
# (213, '호텔에그', 35.0866, 128.879, None, 1, '부산광역시', '강서구', '신호동', 'nan', '216-2', '신호산단1로217번길', '33', 167, 368, 340, 419, 325, 69, 213, 'Y', '호텔')
# (214, '2월호텔 강서신관', 35.087, 128.881, None, 1, '부산광역시', '강서구', '신호동', 'nan', '214-9', '신호산단1로217번길', '12', 197, 460, 305, 472, 208, 64, 214, 'Y', '호텔')
# (215, '모모까르페호텔', 35.0866, 128.881, None, 1, '부산광역시', '강서구', '신호동', 'nan', '213-3', '신호산단1로217번길', '15', 180, 315, 215, 416, 212, 83, 215, 'N', '호텔')
# (216, '브라운도트호텔', 35.0833, 128.871, None, 1, '부산광역시', '강서구', '신호동', 'nan', '317-2', '신호산단1로72번길', '33', 303, 450, 446, 472, 360, 263, 216, 'Y', '호텔')
# (217, '더브레인호텔', 35.0817, 128.872, None, 1, '부산광역시', '강서구', '신호동', 'nan', '315-4', '신호산단1로72번길', '58', 118, 354, 281, 461, 248, 69, 217, 'Y', '호텔')
# (218, '호텔더원', 35.0829, 128.871, None, 1, '부산광역시', '강서구', '신호동', 'nan', '317-5', '신호산단1로72번길', '41', 83, 287, 229, 487, 124, 38, 218, 'Y', '호텔')
# (219, 'V호텔', 35.0864, 128.881, None, 1, '부산광역시', '강서구', '신호동', 'nan', '213-8', '신호산단2로27번길', '33', 131, 269, 249, 344, 176, 130, 219, 'Y', '호텔')
# (220, '비지니스호텔', 35.0864, 128.881, None, 1, '부산광역시', '강서구', '신호동', 'nan', '213-6', '신호산단2로27번길', '41', 214, 351, 326, 486, 323, 64, 220, 'Y', '호텔')
# (221, '펀모텔', 35.0864, 128.88, None, 1, '부산광역시', '강서구', '신호동', 'nan', '213-11', '신호산단2로27번길', '27', 286, 445, 442, 428, 329, 260, 221, 'Y', '모텔')
# (222, '브이모텔', 35.0864, 128.881, None, 1, '부산광역시', '강서구', '신호동', 'nan', '213-8', '신호산단2로27번길', '33', 320, 484, 453, 446, 427, 136, 222, 'N', '모텔')
# (223, '이그니스호텔', 35.0864, 128.879, None, 1, '부산광역시', '강서구', '신호동', 'nan', '216-7', '신호산단2로27번길', '21', 174, 455, 286, 492, 245, 153, 223, 'Y', '호텔')
# (224, '굿프라임호텔', 35.15, 128.831, None, 1, '부산광역시', '강서구', '지사동', 'nan', '1196-4', '과학산단2로', '12', 54, 217, 134, 345, 113, 38, 224, 'Y', '호텔')
# (225, '헤르몬호텔', 35.1501, 128.832, None, 1, '부산광역시', '강서구', '지사동', 'nan', '1197-4', '과학산단2로10번길', '23', 173, 401, 401, 478, 279, 86, 225, 'Y', '호텔')
# (226, '투썸게스트하우스앤펜션', 35.0429, 128.81, None, 1, '부산광역시', '강서구', '천성동', 'nan', '1583', 'nan', 'nan', 402, 253, 275, 448, 435, 232, 226, 'N', '펜션')
# (227, '우리펜션', 35.0257, 128.816, None, 1, '부산광역시', '강서구', '천성동', 'nan', '514', 'nan', 'nan', 244, 145, 185, 359, 265, 37, 227, 'N', '펜션')
# (228, '어울림쉼터펜션', 35.0228, 128.815, None, 1, '부산광역시', '강서구', '천성동', 'nan', '432', '가덕해안로', '883', 314, 77, 291, 410, 406, 68, 228, 'N', '펜션')
# (229, '갈릴리펜션', 35.0305, 128.815, None, 1, '부산광역시', '강서구', '천성동', 'nan', '981', '가덕해안로', '761', 367, 234, 236, 459, 455, 71, 229, 'N', '펜션')
# (230, '카리브의일몰', 35.0334, 128.811, None, 1, '부산광역시', '강서구', '천성동', 'nan', '1335-9', '가덕해안로', '712', 348, 191, 304, 439, 378, 175, 230, 'Y', '펜션')
# (231, '우진펜션', 35.0315, 128.812, None, 1, '부산광역시', '강서구', '천성동', 'nan', '836-1', '가덕해안로', '735', 137, 65, 131, 207, 164, 49, 231, 'Y', '펜션')
# (232, '가덕도그린빌펜션', 35.0374, 128.813, None, 1, '부산광역시', '강서구', '천성동', 'nan', '1447', '가덕해안로665번길', '9', 319, 203, 219, 460, 382, 152, 232, 'N', '펜션')
# (233, '전원별장', 35.037, 128.814, None, 1, '부산광역시', '강서구', '천성동', 'nan', '1437-4', '가덕해안로665번길', '29', 122, 488, 433, 188, 169, 89, 233, 'N', '모텔')
# (234, '가덕부들펜션', 35.0317, 128.825, None, 1, '부산광역시', '강서구', '천성동', 'nan', '101-7', '가덕해안로773번길', '250-1', 314, 77, 312, 474, 358, 65, 234, 'Y', '펜션')
# (235, '로뎀펜션', 35.0317, 128.824, None, 1, '부산광역시', '강서구', '천성동', 'nan', '101-9', '가덕해안로773번길', '238', 269, 154, 218, 424, 356, 44, 235, 'Y', '펜션')
# (236, '꿈에그린펜션', 35.0321, 128.824, None, 1, '부산광역시', '강서구', '천성동', 'nan', '107-3', '가덕해안로773번길', '239', 464, 391, 397, 487, 473, 114, 236, 'Y', '펜션')
# (237, '자연애펜션', 35.0318, 128.825, None, 1, '부산광역시', '강서구', '천성동', 'nan', '101-6', '가덕해안로773번길', '250', 283, 88, 191, 328, 327, 74, 237, 'N', '펜션')
# (238, '가덕도펜션민박', 35.0284, 128.818, None, 1, '부산광역시', '강서구', '천성동', 'nan', '775', '가덕해안로821번길', '90-16', 132, 68, 93, 260, 152, 48, 238, 'Y', '펜션')
# (239, '초록펜션', 35.0266, 128.817, None, 1, '부산광역시', '강서구', '천성동', 'nan', '557', '가덕해안로821번길', '19299', 214, 91, 139, 473, 305, 86, 239, 'Y', '펜션')
# (240, '노을빛펜션', 35.0273, 128.819, None, 1, '부산광역시', '강서구', '천성동', 'nan', '749', '가덕해안로821번길', '60-50', 291, 211, 218, 359, 343, 58, 240, 'Y', '펜션')
# (241, '은행나무펜션', 35.0267, 128.817, None, 1, '부산광역시', '강서구', '천성동', 'nan', '556', '가덕해안로821번길', '19238', 330, 162, 190, 406, 384, 141, 241, 'Y', '펜션')
# (242, '가덕도힐링민박펜션', 35.0273, 128.816, None, 1, '부산광역시', '강서구', '천성동', 'nan', '610', '가덕해안로821번길', '23012', 276, 102, 113, 446, 430, 56, 242, 'Y', '펜션')
# (243, '펜션GALLERY가덕', 35.0341, 128.823, None, 1, '부산광역시', '강서구', '천성동', 'nan', '33', '서천로42번길', '52-32', 233, 105, 231, 299, 260, 77, 243, 'Y', '펜션')
# (244, '백수장', 35.2436, 129.088, None, 1, '부산광역시', '금정구', '구서동', 'nan', '470-1', '금강로', '402', 124, 444, 363, 302, 157, 83, 244, 'N', '모텔')
# (245, '호텔G&G', 35.2449, 129.092, None, 1, '부산광역시', '금정구', '구서동', 'nan', '420-40', '금정로', '242', 112, 426, 301, 463, 141, 80, 245, 'Y', '호텔')
# (246, '카카오호텔', 35.2444, 129.091, None, 1, '부산광역시', '금정구', '구서동', 'nan', '420-52', '금정로', '236', 135, 375, 291, 496, 283, 117, 246, 'Y', '호텔')
# (247, '호텔캔들', 35.2449, 129.09, None, 1, '부산광역시', '금정구', '구서동', 'nan', '415-30', '금정로231번길', '8', 112, 388, 303, 459, 148, 53, 247, 'Y', '호텔')
# (248, '제니스호텔', 35.245, 129.091, None, 1, '부산광역시', '금정구', '구서동', 'nan', '415-28', '금정로233번길', '9', 108, 372, 266, 480, 120, 77, 248, 'Y', '호텔')
# (249, '제니스호텔', 35.245, 129.091, None, 1, '부산광역시', '금정구', '구서동', 'nan', '415-28', '금정로233번길', '9', 61, 319, 182, 442, 93, 38, 249, 'Y', '호텔')
# (250, '쇼모텔', 35.246, 129.092, None, 1, '부산광역시', '금정구', '구서동', 'nan', '30956', '금정로237번길', '14', 163, 346, 257, 252, 164, 31, 250, 'Y', '모텔')
# (251, '호텔야자', 35.2474, 129.092, None, 1, '부산광역시', '금정구', '구서동', 'nan', '31382', '금정로237번길', '28', 262, 392, 382, 411, 289, 166, 251, 'Y', '호텔')
# (252, '9월호텔', 35.2479, 129.092, None, 1, '부산광역시', '금정구', '구서동', 'nan', '31260', '금정로237번길', '34', 119, 420, 354, 499, 232, 77, 252, 'N', '호텔')
# (253, '보브호텔', 35.2476, 129.092, None, 1, '부산광역시', '금정구', '구서동', 'nan', '31352', '금정로237번길', '30', 208, 459, 450, 472, 380, 193, 253, 'N', '호텔')
# (254, '넘버25호텔', 35.248, 129.092, None, 1, '부산광역시', '금정구', '구서동', 'nan', '85-29', '금정로237번길', '36', 205, 419, 323, 495, 250, 189, 254, 'N', '호텔')
# (255, '로즈베이호텔', 35.2479, 129.092, None, 1, '부산광역시', '금정구', '구서동', 'nan', '31260', '금정로237번길', '34', 141, 331, 287, 453, 197, 62, 255, 'N', '호텔')
# (256, '브라운도트 호텔 구서역점', 35.248, 129.092, None, 1, '부산광역시', '금정구', '구서동', 'nan', '31229', '중앙대로', '1833', 209, 402, 367, 468, 301, 48, 256, 'Y', '호텔')
# (257, '티에스호텔', 35.2568, 129.091, None, 1, '부산광역시', '금정구', '구서동', 'nan', '175-12', '중앙대로', '1931', 90, 254, 225, 332, 127, 88, 257, 'Y', '호텔')
# (258, '호텔프렌치코드', 35.2449, 129.092, None, 1, '부산광역시', '금정구', '구서동', 'nan', '420-5', '중앙대로1805번길', '16', 193, 347, 344, 353, 251, 113, 258, 'Y', '호텔')
# (259, '호텔시카고', 35.2572, 129.091, None, 1, '부산광역시', '금정구', '구서동', 'nan', '175-17', '중앙대로1929번길', 'nan', 289, 379, 375, 414, 334, 239, 259, 'Y', '호텔')
# (260, '파크모텔', 35.2567, 129.092, None, 1, '부산광역시', '금정구', '구서동', 'nan', '177-28', '중앙대로1930번길', '9', 341, 496, 476, 473, 396, 39, 260, 'N', '모텔')
# (261, '목화장여관', 35.2577, 129.091, None, 1, '부산광역시', '금정구', '구서동', 'nan', '175-33', '중앙대로1945번길', '9', 131, 402, 368, 305, 195, 45, 261, 'Y', '모텔')
# (262, '드림모텔', 35.2208, 129.113, None, 1, '부산광역시', '금정구', '금사동', 'nan', '24990', '개좌로', '32690', 180, 463, 326, 270, 231, 119, 262, 'Y', '모텔')
# (263, '천우장', 35.2198, 129.112, None, 1, '부산광역시', '금정구', '금사동', 'nan', '68-32', '개좌로', '25934', 123, 475, 348, 202, 200, 51, 263, 'N', '모텔')
# (264, 'V1모텔', 35.2163, 129.111, None, 1, '부산광역시', '금정구', '금사동', 'nan', '104-16', '공단로', '15', 175, 477, 266, 219, 183, 68, 264, 'Y', '모텔')
# (265, 'V1모텔', 35.2163, 129.111, None, 1, '부산광역시', '금정구', '금사동', 'nan', '104-16', '공단로', '15', 278, 444, 407, 395, 388, 83, 265, 'Y', '모텔')
# (266, '새동진장여관', 35.214, 129.109, None, 1, '부산광역시', '금정구', '금사동', 'nan', '145-30', '반송로', '414-1', 163, 426, 261, 220, 213, 154, 266, 'Y', '모텔')
# (267, '조이게스트하우스', 35.2141, 129.109, None, 1, '부산광역시', '금정구', '금사동', 'nan', '145-16', '반송로', '414', 95, 280, 375, 30, 98, 65, 267, 'N', '게스트하우스')
# (268, '새동진장여관', 35.214, 129.109, None, 1, '부산광역시', '금정구', '금사동', 'nan', '145-30', '반송로', '414-1', 168, 458, 326, 261, 175, 71, 268, 'Y', '모텔')
# (269, '휴앤고게스트하우스', 35.2494, 129.059, None, 1, '부산광역시', '금정구', '금성동', 'nan', '592-3', '동문로', '94', 55, 324, 463, 67, 63, 66, 269, 'N', '게스트하우스')
# (270, '쏭하우스', 35.2581, 129.092, None, 1, '부산광역시', '금정구', '남산동', 'nan', 'nan', '중앙대로', '1946', 62, 406, 427, 53, 45, 68, 270, 'N', '게스트하우스')
# (271, '이데아호텔', 35.225, 129.091, None, 1, '부산광역시', '금정구', '부곡동', 'nan', '304-11', '가마실로', '21', 183, 367, 232, 385, 225, 53, 271, 'Y', '호텔')
# (272, '기찰탕여관', 35.2385, 129.093, None, 1, '부산광역시', '금정구', '부곡동', 'nan', '217-9', '무학송로', '79', 167, 388, 382, 354, 321, 100, 272, 'N', '모텔')
# (273, '라찌모텔', 35.2426, 129.091, None, 1, '부산광역시', '금정구', '부곡동', 'nan', '64-24', '중앙대로1763번길', '36-18', 114, 431, 321, 287, 222, 89, 273, 'Y', '모텔')
# (274, '이화모텔', 35.2154, 129.109, None, 1, '부산광역시', '금정구', '서동', 'nan', '207-10', '개좌로', 'nan', 288, 495, 429, 389, 336, 125, 274, 'Y', '모텔')
# (275, '젠모텔', 35.2151, 129.107, None, 1, '부산광역시', '금정구', '서동', 'nan', '204-6', '금사로', 'nan', 182, 455, 383, 367, 351, 122, 275, 'Y', '모텔')
# (276, '파래스', 35.2151, 129.106, None, 1, '부산광역시', '금정구', '서동', 'nan', '203-37', '금사로', 'nan', 252, 430, 364, 310, 281, 179, 276, 'Y', '모텔')
# (277, '부림모텔', 35.2144, 129.108, None, 1, '부산광역시', '금정구', '서동', 'nan', '206-27', '서동로', '193-3', 203, 495, 387, 361, 324, 132, 277, 'N', '모텔')
# (278, '헤이브호텔', 35.2148, 129.108, None, 1, '부산광역시', '금정구', '서동', 'nan', '207-26', '서동로', '193-14', 166, 404, 334, 436, 217, 51, 278, 'Y', '호텔')
# (279, '초원장', 35.2147, 129.107, None, 1, '부산광역시', '금정구', '서동', 'nan', '206-18', '서동로', '187-10', 89, 415, 295, 102, 100, 45, 279, 'N', '모텔')
# (280, '삼성여인숙', 35.2154, 129.102, None, 1, '부산광역시', '금정구', '서동', 'nan', '340-21', '서동로', '145-7', 83, 485, 480, 335, 126, 30, 280, 'N', '모텔')
# (281, '목란장', 35.2143, 129.108, None, 1, '부산광역시', '금정구', '서동', 'nan', '207-8', '서동로', '197-1', 77, 361, 311, 249, 90, 39, 281, 'N', '모텔')
# (282, '호텔 블랑', 35.215, 129.108, None, 1, '부산광역시', '금정구', '서동', 'nan', '206-3', '서동로', '193-15', 94, 413, 292, 452, 285, 42, 282, 'Y', '호텔')
# (283, '넘버25호텔', 35.2148, 129.108, None, 1, '부산광역시', '금정구', '서동', 'nan', '206-4', '서동로', '193-11', 185, 313, 250, 436, 185, 117, 283, 'Y', '호텔')
# (284, '마이홈모텔', 35.215, 129.107, None, 1, '부산광역시', '금정구', '서동', 'nan', '204-3', '서동로175번길', '19', 71, 369, 340, 265, 91, 50, 284, 'N', '모텔')
# (285, '장미별장여관', 35.2142, 129.105, None, 1, '부산광역시', '금정구', '서동', 'nan', '202-7', '서동로176번길', '8', 254, 472, 353, 336, 285, 60, 285, 'N', '모텔')
# (286, '베니스모텔', 35.2139, 129.106, None, 1, '부산광역시', '금정구', '서동', 'nan', '210-7', '서동로186번길', 'nan', 177, 418, 353, 307, 304, 164, 286, 'Y', '모텔')
# (287, '진영장', 35.214, 129.106, None, 1, '부산광역시', '금정구', '서동', 'nan', '210-5', '서동로186번길', '12', 175, 347, 306, 291, 194, 137, 287, 'N', '모텔')
# (288, '청림모텔', 35.214, 129.107, None, 1, '부산광역시', '금정구', '서동', 'nan', '209-25', '서동로186번길', '7', 249, 390, 386, 370, 286, 134, 288, 'N', '모텔')
# (289, '쉐르빌모텔', 35.2138, 129.106, None, 1, '부산광역시', '금정구', '서동', 'nan', '210-8', '서동로186번길', '16', 156, 388, 374, 337, 297, 136, 289, 'N', '모텔')
# (290, '진영모텔', 35.214, 129.106, None, 1, '부산광역시', '금정구', '서동', 'nan', '210-5', '서동로186번길', '12', 45, 485, 347, 288, 215, 34, 290, 'Y', '모텔')
# (291, '아마존모텔', 35.2133, 129.107, None, 1, '부산광역시', '금정구', '서동', 'nan', '208-19', '서동로194번길', '21', 402, 481, 469, 443, 427, 81, 291, 'Y', '모텔')
# (292, '그랜드모텔', 35.2138, 129.107, None, 1, '부산광역시', '금정구', '서동', 'nan', '209-41', '서동로194번길', '12', 147, 441, 433, 269, 267, 129, 292, 'Y', '모텔')
# (293, '몽블랑모텔', 35.214, 129.108, None, 1, '부산광역시', '금정구', '서동', 'nan', '208-18', '서동로194번길', '3', 147, 484, 364, 263, 167, 111, 293, 'Y', '모텔')
# (294, '마모텔', 35.214, 129.107, None, 1, '부산광역시', '금정구', '서동', 'nan', '209-3', '서동로194번길', '8', 364, 460, 443, 436, 416, 57, 294, 'Y', '모텔')
# (295, '금오별장', 35.2139, 129.107, None, 1, '부산광역시', '금정구', '서동', 'nan', '208-6', '서동로194번길', '7', 78, 467, 302, 271, 100, 37, 295, 'N', '모텔')
# (296, '동산여인숙', 35.2177, 129.096, None, 1, '부산광역시', '금정구', '서동', 'nan', '520-233', '서동로79번길', '17', 183, 407, 388, 372, 248, 181, 296, 'N', '모텔')
# (297, '제일여인숙', 35.2166, 129.102, None, 1, '부산광역시', '금정구', '서동', 'nan', '302-31', '서동시장뒷길', '43', 136, 452, 349, 341, 291, 129, 297, 'N', '모텔')
# (298, '동진여관', 35.214, 129.103, None, 1, '부산광역시', '금정구', '서동', 'nan', '294-9', '서동중심로', '57', 160, 473, 471, 280, 176, 110, 298, 'N', '모텔')
# (299, '빙고모텔', 35.2153, 129.106, None, 1, '부산광역시', '금정구', '서동', 'nan', '203-1', '서부로4번길', '16', 310, 492, 463, 453, 441, 101, 299, 'Y', '모텔')
# (300, '목화모텔', 35.2577, 129.091, None, 1, '부산광역시', '금정구', '온천동', 'nan', '444-78', '중앙대로1945번길', '9', 199, 437, 435, 367, 236, 113, 300, 'N', '모텔')
# (301, '동평장여관', 35.225, 129.082, None, 1, '부산광역시', '금정구', '장전동', 'nan', '580-3', 'nan', 'nan', 50, 420, 337, 240, 198, 35, 301, 'N', '모텔')
# (302, '새온천모텔찜질방', 35.2241, 129.082, None, 1, '부산광역시', '금정구', '장전동', 'nan', '595-5', '금강로', '173-3', 76, 433, 319, 137, 123, 33, 302, 'Y', '모텔')
# (303, '송원장', 35.2238, 129.081, None, 1, '부산광역시', '금정구', '장전동', 'nan', '594-8', '금강로', '169', 231, 500, 419, 392, 300, 96, 303, 'N', '모텔')
# (304, '금성여인숙', 35.225, 129.082, None, 1, '부산광역시', '금정구', '장전동', 'nan', '576-14', '금강로', '185', 47, 480, 308, 198, 64, 32, 304, 'N', '모텔')
# (305, '쉴라게스트하우스', 35.2366, 129.084, None, 1, '부산광역시', '금정구', '장전동', 'nan', '263-41', '금강로279번길', '111', 74, 427, 310, 55, 34, 83, 305, 'N', '게스트하우스')
# (306, 'BUSANSPAGUESTHOUSE', 35.2349, 129.083, None, 1, '부산광역시', '금정구', '장전동', 'nan', '269-3', '금강로279번길', '61', 46, 292, 281, 94, 54, 38, 306, 'N', '게스트하우스')
# (307, '단디하우스부산대', 35.2349, 129.088, None, 1, '부산광역시', '금정구', '장전동', 'nan', '382-26', '금정로', '116', 58, 300, 338, 85, 98, 62, 307, 'N', '게스트하우스')
# (308, '부산사랑게스트하우스', 35.231, 129.086, None, 1, '부산광역시', '금정구', '장전동', 'nan', '421-3', '금정로', '71', 75, 412, 227, 66, 77, 41, 308, 'N', '게스트하우스')
# (309, '웁스모텔', 35.2243, 129.085, None, 1, '부산광역시', '금정구', '장전동', 'nan', '605-11', '식물원로27번길', '6', 66, 482, 325, 239, 107, 38, 309, 'N', '모텔')
# (310, '올레모텔', 35.2236, 129.084, None, 1, '부산광역시', '금정구', '장전동', 'nan', '604-10', '식물원로29번길', '25', 170, 458, 454, 325, 281, 165, 310, 'Y', '모텔')
# (311, '로망스모텔', 35.2227, 129.086, None, 1, '부산광역시', '금정구', '장전동', 'nan', '649-20', '식물원로9번길', '29', 54, 345, 292, 160, 58, 34, 311, 'Y', '모텔')
# (312, '맥스모텔', 35.2226, 129.085, None, 1, '부산광역시', '금정구', '장전동', 'nan', '652-21', '온천장로125번길', '10', 231, 492, 470, 428, 364, 60, 312, 'Y', '모텔')
# (313, '모텔델루나', 35.2244, 129.082, None, 1, '부산광역시', '금정구', '장전동', 'nan', '617-12', '온천장로125번길', '27181', 189, 455, 379, 375, 248, 130, 313, 'Y', '모텔')
# (314, '대도여관', 35.2234, 129.084, None, 1, '부산광역시', '금정구', '장전동', 'nan', '604-30', '온천장로125번길', 'nan', 114, 444, 281, 213, 149, 66, 314, 'Y', '모텔')
# (315, '아라모텔', 35.2225, 129.085, None, 1, '부산광역시', '금정구', '장전동', 'nan', '652-75', '온천장로125번길', '8', 85, 413, 286, 283, 202, 81, 315, 'Y', '모텔')
# (316, '아레스모텔', 35.2234, 129.084, None, 1, '부산광역시', '금정구', '장전동', 'nan', '604-48', '온천장로125번길', '28-14', 138, 474, 402, 349, 175, 121, 316, 'N', '모텔')
# (317, '만리장여관', 35.2238, 129.083, None, 1, '부산광역시', '금정구', '장전동', 'nan', '601-10', '온천장로125번안길', '6', 146, 497, 440, 391, 321, 106, 317, 'N', '모텔')
# (318, '팔레스모텔', 35.2771, 129.089, None, 1, '부산광역시', '금정구', '청룡동', 'nan', '14550', '남산냇길', '121', 72, 429, 372, 274, 207, 56, 318, 'N', '모텔')
# (319, '청룡여관', 35.2754, 129.089, None, 1, '부산광역시', '금정구', '청룡동', 'nan', 'nan', '청룡로', '31', 234, 461, 434, 421, 343, 84, 319, 'Y', '모텔')
# (320, '유성장모텔', 35.2757, 129.089, None, 1, '부산광역시', '금정구', '청룡동', 'nan', '16132', '청룡로', '32', 165, 483, 373, 371, 199, 147, 320, 'Y', '모텔')
# (321, '범어장', 35.2739, 129.092, None, 1, '부산광역시', '금정구', '청룡동', 'nan', 'nan', '청룡예전로', '5', 128, 448, 266, 208, 185, 60, 321, 'Y', '모텔')
# (322, '범어장모텔', 35.2739, 129.092, None, 1, '부산광역시', '금정구', '청룡동', 'nan', 'nan', '청룡예전로', '5', 96, 433, 407, 294, 104, 63, 322, 'Y', '모텔')
# (323, '에스모텔', 35.2775, 129.089, None, 1, '부산광역시', '금정구', '청룡동', 'nan', '14397', '청룡예전로43번길', '17', 234, 449, 354, 308, 267, 194, 323, 'Y', '모텔')
# (324, '니즈호텔', 35.2745, 129.09, None, 1, '부산광역시', '금정구', '청룡동', 'nan', '12175', '팔송로24번길', '52', 324, 424, 410, 492, 354, 250, 324, 'Y', '호텔')
# (325, '그루브펜션', 35.1862, 129.208, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '694', 'nan', 'nan', 195, 53, 82, 459, 403, 48, 325, 'N', '펜션')
# (326, '모닝블루펜션', 35.1848, 129.213, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '545-1', '공수해안길', '25', 107, 57, 82, 370, 366, 36, 326, 'Y', '펜션')
# (327, '바다애펜션', 35.186, 129.213, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '540-5', '공수해안길', '20852', 260, 147, 238, 426, 306, 83, 327, 'Y', '펜션')
# (328, '오시리아펜션', 35.1881, 129.218, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '453-21', '공수해안길', '112', 350, 93, 253, 470, 415, 47, 328, 'Y', '펜션')
# (329, '시나몬하우스앤카페', 35.1845, 129.211, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '581', '공수해안길', '15', 67, 414, 299, 31, 83, 86, 329, 'N', '게스트하우스')
# (330, '가온펜션', 35.1845, 129.213, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '545-7', '공수해안길', 'nan', 407, 179, 240, 490, 472, 57, 330, 'Y', '펜션')
# (331, '타샤모텔', 35.2349, 129.215, None, 1, '부산광역시', '기장군', '기장읍', '청강리', '705-6', '기장대로413번길', '32', 187, 461, 359, 332, 281, 64, 331, 'Y', '모텔')
# (332, '골든베이펜션', 35.2213, 129.227, None, 1, '부산광역시', '기장군', '기장읍', '대변리', '288', '기장해안로', '536', 303, 143, 259, 421, 393, 96, 332, 'Y', '펜션')
# (333, '고마펜션', 35.235, 129.243, None, 1, '부산광역시', '기장군', '기장읍', '죽성리', '402', '기장해안로', '899-2', 421, 360, 403, 485, 432, 217, 333, 'Y', '펜션')
# (334, '본레브연화리330풀빌라앤호텔', 35.2156, 129.223, None, 1, '부산광역시', '기장군', '기장읍', '연화리', '330-2', '기장해안로', '460', 173, 422, 420, 489, 412, 135, 334, 'Y', '호텔')
# (335, 'MVG모텔', 35.2139, 129.222, None, 1, '부산광역시', '기장군', '기장읍', '연화리', '372-6', '기장해안로', '438', 231, 435, 291, 267, 232, 156, 335, 'Y', '모텔')
# (336, '연화리관광호텔', 35.2156, 129.223, None, 1, '부산광역시', '기장군', '기장읍', '연화리', '330-2', '기장해안로', '460', 174, 414, 306, 496, 255, 167, 336, 'Y', '호텔')
# (337, '호텔오즈', 35.2208, 129.227, None, 1, '부산광역시', '기장군', '기장읍', '대변리', '277-1', '기장해안로', '530', 219, 464, 416, 468, 275, 158, 337, 'Y', '호텔')
# (338, '타이드어웨이풀빌라', 35.1822, 129.209, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '615-5', '기장해안로', '26', 427, 223, 286, 495, 472, 200, 338, 'Y', '펜션')
# (339, '로드엠게스트하우스펜션', 35.2238, 129.231, None, 1, '부산광역시', '기장군', '기장읍', '대변리', '308-2', '기장해안로', '615-6', 408, 138, 278, 500, 476, 90, 339, 'Y', '펜션')
# (340, '연화펜션', 35.2137, 129.222, None, 1, '부산광역시', '기장군', '기장읍', '연화리', '379-1', '기장해안로', '434', 308, 211, 291, 476, 416, 109, 340, 'Y', '펜션')
# (341, '지앤지모텔', 35.2142, 129.222, None, 1, '부산광역시', '기장군', '기장읍', '연화리', '372-1', '기장해안로', '442', 141, 459, 377, 289, 259, 108, 341, 'Y', '모텔')
# (342, 'MVG무인텔', 35.2139, 129.222, None, 1, '부산광역시', '기장군', '기장읍', '연화리', '372-6', '기장해안로', '438', 67, 480, 440, 403, 268, 41, 342, 'Y', '모텔')
# (343, '아난티 힐튼 부산', 35.198, 129.228, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '704-1', '기장해안로', '268-32', 193, 311, 296, 445, 256, 49, 343, 'Y', '호텔')
# (344, '꿈의궁전모텔', 35.2223, 129.227, None, 1, '부산광역시', '기장군', '기장읍', '대변리', '203-6', '기장해안로', '546', 54, 318, 217, 123, 99, 52, 344, 'Y', '모텔')
# (345, '오즈모텔', 35.2208, 129.227, None, 1, '부산광역시', '기장군', '기장읍', '대변리', '277-1', '기장해안로', '530', 159, 495, 462, 394, 237, 72, 345, 'Y', '모텔')
# (346, '별이그린바다펜션', 35.1822, 129.211, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '630-3', '기장해안로', '34-18', 395, 344, 358, 474, 446, 316, 346, 'Y', '펜션')
# (347, '아난티코브', 35.1997, 129.229, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '704', '기장해안로', '268-31', 217, 396, 344, 441, 250, 98, 347, 'Y', '호텔')
# (348, '필모텔', 35.2138, 129.222, None, 1, '부산광역시', '기장군', '기장읍', '연화리', '378-1', '기장해안로', '436', 258, 468, 466, 411, 350, 254, 348, 'N', '모텔')
# (349, '기장숲속농원캠프', 35.2188, 129.183, None, 1, '부산광역시', '기장군', '기장읍', '내리', '664', '내리길', '336', 205, 492, 434, 303, 216, 152, 349, 'Y', '모텔')
# (350, '사랑애펜션', 35.2378, 129.242, None, 1, '부산광역시', '기장군', '기장읍', '죽성리', '481-1', '달밭길', '10', 180, 130, 134, 399, 222, 107, 350, 'Y', '펜션')
# (351, '휴인펜션', 35.1846, 129.21, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '686-7', '당사로1길', '21', 189, 87, 161, 394, 262, 85, 351, 'Y', '펜션')
# (352, '더하루펜션', 35.1853, 129.21, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '686-2', '당사로1길', '13', 262, 205, 237, 466, 364, 40, 352, 'Y', '펜션')
# (353, '마루하우스펜션', 35.1862, 129.211, None, 1, '부산광역시', '기장군', '기장읍', '당사리', '506-1', '당사로1길', '1', 166, 35, 54, 308, 209, 35, 353, 'Y', '펜션')
# (354, '아라하우스펜션', 35.184, 129.21, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '691-2', '당사로1길', '30', 258, 59, 195, 328, 316, 57, 354, 'Y', '펜션')
# (355, '더베이펜션', 35.1844, 129.21, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '686-8', '당사로1길', '23', 346, 266, 303, 449, 365, 249, 355, 'Y', '펜션')
# (356, '솔레이펜션', 35.1837, 129.21, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '692-2', '당사로1길', '31', 223, 83, 126, 352, 238, 69, 356, 'Y', '펜션')
# (357, '브라이트펜션', 35.1847, 129.21, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '686-6', '당사로1길', '19', 407, 110, 312, 489, 424, 107, 357, 'Y', '펜션')
# (358, '부산라메르펜션', 35.1849, 129.21, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '686-4', '당사로1길', '17', 224, 99, 175, 495, 365, 78, 358, 'Y', '펜션')
# (359, '백용펜션', 35.1847, 129.21, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '685-7', '당사로1길', '20', 477, 319, 429, 500, 489, 58, 359, 'Y', '펜션')
# (360, '더펜션502', 35.1881, 129.211, None, 1, '부산광역시', '기장군', '기장읍', '당사리', '502-2', '당사로2길', '21', 262, 40, 237, 484, 440, 38, 360, 'Y', '펜션')
# (361, '해오름펜션', 35.1878, 129.211, None, 1, '부산광역시', '기장군', '기장읍', '당사리', '502-4', '당사로2길', '17', 332, 163, 305, 386, 346, 141, 361, 'Y', '펜션')
# (362, 'J&J하우스', 35.188, 129.211, None, 1, '부산광역시', '기장군', '기장읍', '당사리', '502-3', '당사로2길', '19', 69, 407, 265, 67, 84, 43, 362, 'Y', '게스트하우스')
# (363, '바우하우스펜션', 35.1848, 129.21, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '685-10', '당사로3길', '19', 257, 225, 241, 442, 332, 202, 363, 'Y', '펜션')
# (364, '송정로뎀나무펜션', 35.1849, 129.21, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '688-1', '당사로3길', '20', 327, 105, 126, 384, 377, 87, 364, 'Y', '펜션')
# (365, '메종펜션', 35.1839, 129.209, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '691-6', '당사로3길', '31', 184, 115, 180, 382, 240, 108, 365, 'Y', '펜션')
# (366, '그루브펜션', 35.1861, 129.208, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '680-1', '당사로5길', '17', 334, 177, 180, 494, 427, 161, 366, 'Y', '펜션')
# (367, '오시리아인펜션', 35.1852, 129.209, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '683-6', '당사로5길', 'nan', 323, 83, 214, 396, 342, 82, 367, 'Y', '펜션')
# (368, '송정 메이플하우스', 35.1854, 129.21, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '683-4', '당사로5길', 'nan', 38, 221, 400, 95, 42, 42, 368, 'Y', '게스트하우스')
# (369, '송정드림펜션', 35.1849, 129.209, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '687-5', '당사로5길', '44', 276, 124, 182, 338, 330, 77, 369, 'Y', '펜션')
# (370, '팰리스모텔', 35.2339, 129.219, None, 1, '부산광역시', '기장군', '기장읍', '청강리', '337-2', '대변로', '24', 182, 403, 361, 302, 229, 35, 370, 'Y', '모텔')
# (371, '더원모텔', 35.2272, 129.227, None, 1, '부산광역시', '기장군', '기장읍', '대변리', '433-2', '대변로', '133', 130, 403, 307, 306, 132, 110, 371, 'Y', '모텔')
# (372, '하얀둥지펜션', 35.2274, 129.227, None, 1, '부산광역시', '기장군', '기장읍', '대변리', '433-3', '대변로', '131', 179, 84, 141, 483, 340, 74, 372, 'Y', '펜션')
# (373, '올리브모텔', 35.2341, 129.219, None, 1, '부산광역시', '기장군', '기장읍', '청강리', '335-3', '대변로', '20', 177, 400, 258, 210, 196, 65, 373, 'N', '모텔')
# (374, '비너스모텔', 35.2331, 129.219, None, 1, '부산광역시', '기장군', '기장읍', '청강리', '348-4', '대변로', '32', 127, 489, 290, 157, 128, 62, 374, 'N', '모텔')
# (375, '부산 기장 휴', 35.2348, 129.215, None, 1, '부산광역시', '기장군', '기장읍', '청강리', '705-5', '대청로72번길', 'nan', 54, 484, 481, 420, 265, 38, 375, 'Y', '모텔')
# (376, '시랑리129펜션', 35.1966, 129.225, None, 1, '부산광역시', '기장군', '기장읍', '시랑리', '129', '동암1길', '27', 378, 182, 302, 497, 487, 89, 376, 'Y', '펜션')
# (377, '드림하우스펜션', 35.2403, 129.248, None, 1, '부산광역시', '기장군', '기장읍', '죽성리', '141-1', '두호1길', 'nan', 342, 153, 280, 460, 390, 31, 377, 'Y', '펜션')
# (378, '죽성여관', 35.2407, 129.247, None, 1, '부산광역시', '기장군', '기장읍', '죽성리', '196-1', '두호길', '31', 103, 397, 381, 221, 156, 40, 378, 'N', '모텔')
# (379, 'TOC모텔', 35.2514, 129.208, None, 1, '부산광역시', '기장군', '기장읍', '서부리', '383', '반송로', '1523', 120, 481, 364, 205, 122, 95, 379, 'Y', '모텔')
# (380, '모텔헤이데이', 35.2493, 129.21, None, 1, '부산광역시', '기장군', '기장읍', '서부리', '432', '반송로', '1547', 121, 412, 388, 297, 275, 33, 380, 'Y', '모텔')
# (381, '베스트루이스해밀턴호텔 기장점', 35.2495, 129.21, None, 1, '부산광역시', '기장군', '기장읍', '서부리', '422', '반송로', '1545', 146, 240, 160, 363, 153, 63, 381, 'Y', '호텔')
# (382, '2001HAMILTONHOTEL', 35.2495, 129.21, None, 1, '부산광역시', '기장군', '기장읍', '서부리', '422', '반송로', '1545', 116, 212, 195, 470, 135, 50, 382, 'N', '호텔')
# (383, '모텔헤이데이', 35.2493, 129.21, None, 1, '부산광역시', '기장군', '기장읍', '서부리', '432', '반송로', '1547', 87, 470, 448, 391, 309, 62, 383, 'Y', '모텔')
# (384, '베스트루이스해밀턴호텔', 35.2495, 129.21, None, 1, '부산광역시', '기장군', '기장읍', '서부리', '422', '반송로', '1545', 198, 307, 248, 347, 218, 87, 384, 'Y', '호텔')
# (385, '서랑펜션', 35.201, 129.206, None, 1, '부산광역시', '기장군', '기장읍', '내리', '204-1', '소정길', '11', 327, 77, 190, 360, 353, 69, 385, 'Y', '펜션')
# (386, '펜션드리머', 35.217, 129.225, None, 1, '부산광역시', '기장군', '기장읍', '연화리', '222-5', '연화2길', '5', 291, 251, 280, 427, 341, 78, 386, 'Y', '펜션')
# (387, '필모텔', 35.2161, 129.225, None, 1, '부산광역시', '기장군', '기장읍', '연화리', '292', '연화길', '28', 241, 499, 484, 380, 313, 205, 387, 'N', '모텔')
# (388, '엔줄리오펜션', 35.2153, 129.223, None, 1, '부산광역시', '기장군', '기장읍', '연화리', '326-2', '연화길', '10', 358, 249, 255, 496, 398, 185, 388, 'Y', '펜션')
# (389, '기장브라운도트펜션', 35.2179, 129.225, None, 1, '부산광역시', '기장군', '기장읍', '연화리', '214-14', '연화길', '16803', 275, 226, 263, 431, 311, 48, 389, 'Y', '펜션')
# (390, 'IW모텔', 35.2205, 129.227, None, 1, '부산광역시', '기장군', '기장읍', '대변리', '277-2', '연화길', '76', 72, 467, 372, 170, 170, 31, 390, 'Y', '모텔')
# (391, '브라운도트호텔', 35.2179, 129.226, None, 1, '부산광역시', '기장군', '기장읍', '연화리', '214-6', '연화길', '16923', 180, 342, 245, 476, 240, 107, 391, 'Y', '호텔')
# (392, '넘버이십오', 35.2192, 129.226, None, 1, '부산광역시', '기장군', '기장읍', '연화리', '109-1', '연화길', '64', 241, 417, 414, 473, 344, 51, 392, 'Y', '호텔')
# (393, '초콜릿모텔', 35.2164, 129.225, None, 1, '부산광역시', '기장군', '기장읍', '연화리', '292-1', '연화길', '32', 215, 451, 347, 253, 251, 160, 393, 'Y', '모텔')
# (394, '기장호텔', 35.2415, 129.214, None, 1, '부산광역시', '기장군', '기장읍', '대라리', '126-8', '차성남로', '57', 208, 445, 347, 464, 212, 99, 394, 'N', '호텔')
# (395, '루이스호텔', 35.2417, 129.216, None, 1, '부산광역시', '기장군', '기장읍', '대라리', '81-33', '차성동로45번길', '13', 163, 313, 236, 418, 174, 71, 395, 'Y', '호텔')
# (396, '기장루이스호텔', 35.2417, 129.216, None, 1, '부산광역시', '기장군', '기장읍', '대라리', '81-33', '차성동로45번길', '13', 94, 250, 246, 468, 136, 72, 396, 'Y', '호텔')
# (397, '드림모텔', 35.253, 129.214, None, 1, '부산광역시', '기장군', '기장읍', '교리', '331-2', '차성로', '398', 216, 441, 399, 366, 269, 195, 397, 'Y', '모텔')
# (398, '호텔리안', 35.2504, 129.214, None, 1, '부산광역시', '기장군', '기장읍', '동부리', '386-8', '차성로', '367', 176, 256, 243, 324, 210, 160, 398, 'N', '호텔')
# (399, '부띠끄호텔 오월로', 35.2501, 129.214, None, 1, '부산광역시', '기장군', '기장읍', '동부리', '393-1', '차성로', '365', 111, 211, 166, 484, 148, 100, 399, 'Y', '호텔')
# (400, '브룩스호텔', 35.2507, 129.214, None, 1, '부산광역시', '기장군', '기장읍', '동부리', '386-5', '차성로', '371', 213, 473, 422, 500, 221, 99, 400, 'Y', '호텔')
# (401, '부띠끄호텔 오월로', 35.2501, 129.214, None, 1, '부산광역시', '기장군', '기장읍', '동부리', '393-1', '차성로', '365', 208, 286, 241, 386, 215, 186, 401, 'Y', '호텔')
# (402, '이데아호텔', 35.2536, 129.214, None, 1, '부산광역시', '기장군', '기장읍', '교리', '324-6', '차성로', '403', 215, 372, 334, 484, 292, 130, 402, 'Y', '호텔')
# (403, '2PM호텔', 35.2507, 129.214, None, 1, '부산광역시', '기장군', '기장읍', '동부리', '386-5', '차성로', '371', 116, 387, 300, 432, 253, 92, 403, 'Y', '호텔')
# (404, '큐모텔', 35.2506, 129.214, None, 1, '부산광역시', '기장군', '기장읍', '교리', '329-5', '차성로', '370', 207, 417, 389, 330, 299, 119, 404, 'Y', '모텔')
# (405, 'HOTEL페오', 35.2532, 129.214, None, 1, '부산광역시', '기장군', '기장읍', '교리', '324-9', '차성로', '397', 124, 282, 162, 386, 151, 98, 405, 'Y', '호텔')
# (406, '짱모텔', 35.2511, 129.214, None, 1, '부산광역시', '기장군', '기장읍', '동부리', '386-2', '차성로', '375', 115, 468, 254, 168, 162, 76, 406, 'Y', '모텔')
# (407, '넘버25호텔', 35.2523, 129.214, None, 1, '부산광역시', '기장군', '기장읍', '교리', '330-15', '차성로', '390', 241, 325, 277, 455, 271, 111, 407, 'Y', '호텔')
# (408, '힐모텔', 35.253, 129.215, None, 1, '부산광역시', '기장군', '기장읍', '교리', '331-3', '차성로404번길', '14', 238, 404, 310, 277, 257, 33, 408, 'Y', '모텔')
# (409, '지오클럽캠핑장', 35.2577, 129.236, None, 1, '부산광역시', '기장군', '일광면', '삼성리', '149-1', 'nan', 'nan', 66, 468, 221, 159, 73, 52, 409, 'N', '모텔')
# (410, '일광민박딴따라', 35.2629, 129.234, None, 1, '부산광역시', '기장군', '일광면', '삼성리', '115-2', 'nan', 'nan', 392, 94, 224, 429, 459, 429, 410, 'N', '모텔')
# (411, '민캠프힐링오토캠핑장', 35.2898, 129.234, None, 1, '부산광역시', '기장군', '일광면', '화전리', 'nan', '기장대로', '1075-6', 61, 470, 149, 145, 86, 58, 411, 'Y', '모텔')
# (412, '일광추억이머무르는곳', 35.2626, 129.233, None, 1, '부산광역시', '기장군', '일광면', '삼성리', '109-5', '기장해안로', '1331', 113, 102, 109, 193, 447, 304, 412, 'N', '모텔')
# (413, '일출민박', 35.2596, 129.233, None, 1, '부산광역시', '기장군', '일광면', '삼성리', '716-2', '기장해안로', '1297', 198, 125, 136, 238, 488, 351, 413, 'N', '모텔')
# (414, '채움펜션', 35.3033, 129.258, None, 1, '부산광역시', '기장군', '일광면', '문중리', '35796', '문오성길', '629', 384, 147, 214, 484, 472, 108, 414, 'Y', '펜션')
# (415, '메모리펜션', 35.2828, 129.259, None, 1, '부산광역시', '기장군', '일광면', '동백리', '266-6', '문오성길', '61', 372, 174, 210, 471, 421, 68, 415, 'N', '펜션')
# (416, '바다펜션', 35.2828, 129.259, None, 1, '부산광역시', '기장군', '일광면', '동백리', '278-1', '문오성길', '51', 179, 49, 179, 257, 204, 45, 416, 'N', '펜션')
# (417, '비치하임펜션', 35.3073, 129.259, None, 1, '부산광역시', '기장군', '일광면', '문동리', '205-1', '문오성길', '727', 378, 195, 328, 463, 462, 147, 417, 'Y', '펜션')
# (418, '몽블랑모텔', 35.2645, 129.234, None, 1, '부산광역시', '기장군', '일광면', '삼성리', '13547', '삼성1길', '6', 229, 474, 401, 373, 233, 227, 418, 'Y', '모텔')
# (419, '캐슬모텔', 35.2649, 129.234, None, 1, '부산광역시', '기장군', '일광면', '삼성리', '13271', '삼성1길', 'nan', 98, 408, 287, 180, 151, 47, 419, 'Y', '모텔')
# (420, '쉼표모텔', 35.2647, 129.235, None, 1, '부산광역시', '기장군', '일광면', '삼성리', '12936', '삼성1길', '13', 259, 445, 439, 363, 288, 74, 420, 'Y', '모텔')
# (421, '해나무민박', 35.2627, 129.233, None, 1, '부산광역시', '기장군', '일광면', '삼성리', '115-41', '삼성3길', 'nan', 158, 96, 141, 231, 461, 298, 421, 'N', '모텔')
# (422, '늘봄모텔', 35.2658, 129.234, None, 1, '부산광역시', '기장군', '일광면', '삼성리', '12359', '삼성3길', '19419', 362, 488, 437, 371, 368, 234, 422, 'Y', '모텔')
# (423, '즐거운민박', 35.2638, 129.234, None, 1, '부산광역시', '기장군', '일광면', '삼성리', '14489', '삼성3길', '25', 300, 35, 187, 304, 490, 320, 423, 'N', '모텔')
# (424, '삼성장펜션', 35.2633, 129.234, None, 1, '부산광역시', '기장군', '일광면', '삼성리', '15342', '삼성길', 'nan', 251, 207, 250, 358, 344, 40, 424, 'Y', '펜션')
# (425, '제이스펜션&글램핑', 35.2772, 129.234, None, 1, '부산광역시', '기장군', '일광면', '화전리', '135', '이천8길', '132-20', 217, 105, 158, 270, 256, 73, 425, 'Y', '펜션')
# (426, '일광하우스', 35.2649, 129.239, None, 1, '부산광역시', '기장군', '일광면', '이천리', '387', '이천길', '18629', 63, 243, 267, 95, 73, 69, 426, 'N', '게스트하우스')
# (427, '바베네캠핑장', 35.2729, 129.254, None, 1, '부산광역시', '기장군', '일광면', '이천리', '132-1', '일광로', '334', 142, 290, 240, 172, 146, 106, 427, 'N', '모텔')
# (428, '일광펜션', 35.3127, 129.261, None, 1, '부산광역시', '기장군', '일광면', '문동리', '46', '일광로', '806', 394, 194, 256, 407, 401, 184, 428, 'Y', '펜션')
# (429, '기장메이트펜션', 35.3108, 129.26, None, 1, '부산광역시', '기장군', '일광면', '문동리', 'nan', '일광로', '783', 326, 176, 244, 342, 339, 169, 429, 'N', '펜션')
# (430, '모아펜션', 35.3125, 129.261, None, 1, '부산광역시', '기장군', '일광면', '문동리', '07-11', '일광로', '804', 113, 99, 111, 448, 336, 56, 430, 'Y', '펜션')
# (431, '리버사이드펜션', 35.2929, 129.26, None, 1, '부산광역시', '기장군', '일광면', '신평리', '7', '일광로', '582-44', 201, 95, 115, 488, 462, 87, 431, 'Y', '펜션')
# (432, '일광메모리펜션', 35.2828, 129.259, None, 1, '부산광역시', '기장군', '일광면', '동백리', '256', '일광로', '474', 155, 83, 129, 333, 251, 73, 432, 'N', '펜션')
# (433, '사계절펜션', 35.3117, 129.26, None, 1, '부산광역시', '기장군', '일광면', '문동리', 'nan', '일광로', '795', 272, 167, 196, 363, 314, 130, 433, 'N', '펜션')
# (434, '드메르펜션', 35.2924, 129.26, None, 1, '부산광역시', '기장군', '일광면', '신평리', '4', '일광로', '582-48', 430, 261, 417, 496, 489, 154, 434, 'Y', '펜션')
# (435, '바다하우스', 35.2935, 129.26, None, 1, '부산광역시', '기장군', '일광면', '신평리', 'nan', '일광로', '582-28', 45, 271, 304, 42, 79, 58, 435, 'N', '게스트하우스')
# (436, '별장민박', 35.3123, 129.261, None, 1, '부산광역시', '기장군', '일광면', '문동리', 'nan', '일광로', '798', 318, 71, 297, 328, 434, 343, 436, 'N', '모텔')
# (437, '큐모텔', 35.2641, 129.233, None, 1, '부산광역시', '기장군', '일광면', '삼성리', '13820', '일광로', '32143', 159, 354, 351, 255, 224, 114, 437, 'N', '모텔')
# (438, '알로하펜션', 35.2939, 129.26, None, 1, '부산광역시', '기장군', '일광면', '신평리', 'nan', '일광로', '582-14', 280, 141, 199, 476, 454, 130, 438, 'Y', '펜션')
# (439, '발리모텔', 35.2621, 129.232, None, 1, '부산광역시', '기장군', '일광면', '삼성리', '711-3', '일역길', '34759', 243, 495, 408, 308, 259, 176, 439, 'Y', '모텔')
# (440, '아셀펜션', 35.2618, 129.233, None, 1, '부산광역시', '기장군', '일광면', '삼성리', '109-19', '일역길', '84', 277, 186, 230, 366, 289, 110, 440, 'N', '펜션')
# (441, '어베인', 35.2612, 129.233, None, 1, '부산광역시', '기장군', '일광면', '삼성리', '714-2', '일역길', '28491', 322, 279, 312, 497, 357, 33, 441, 'N', '펜션')
# (442, '1872팡시온펜션', 35.2578, 129.244, None, 1, '부산광역시', '기장군', '일광면', '학리', '187-2', '학리길', 'nan', 259, 135, 245, 475, 385, 82, 442, 'Y', '펜션')
# (443, '부산해운대1872팡시온', 35.2577, 129.244, None, 1, '부산광역시', '기장군', '일광면', '학리', '187-2', '학리길', 'nan', 121, 95, 101, 466, 227, 54, 443, 'Y', '펜션')
# (444, '메르쏭하우스', 35.2581, 129.243, None, 1, '부산광역시', '기장군', '일광면', '학리', '275-1', '학리길', 'nan', 86, 403, 443, 45, 61, 76, 444, 'Y', '게스트하우스')
# (445, '하루펜션', 35.2586, 129.243, None, 1, '부산광역시', '기장군', '일광면', '학리', '267-1', '학리길', 'nan', 226, 59, 222, 461, 254, 42, 445, 'Y', '펜션')
# (446, '고운학리펜션', 35.2584, 129.243, None, 1, '부산광역시', '기장군', '일광면', '학리', '276-2', '학리길', 'nan', 269, 253, 259, 443, 280, 90, 446, 'Y', '펜션')
# (447, '라고마르펜션', 35.2589, 129.243, None, 1, '부산광역시', '기장군', '일광면', '학리', '269-1', '학리길', '13-13', 429, 138, 219, 472, 444, 57, 447, 'Y', '펜션')
# (448, '하운드호텔', 35.2655, 129.231, None, 1, '부산광역시', '기장군', '일광면', '삼성리', '890-4', '해송3로', '2', 206, 348, 346, 349, 211, 191, 448, 'N', '호텔')
# (449, '농촌체험민박집', 35.2964, 129.203, None, 1, '부산광역시', '기장군', '일광면', '용천리', '674-2', '화용길', '366', 293, 89, 252, 321, 456, 430, 449, 'N', '모텔')
# (450, '일광횡계민박', 35.2717, 129.222, None, 1, '부산광역시', '기장군', '일광면', '횡계리', '146', '횡계길', '87', 128, 78, 88, 135, 265, 167, 450, 'Y', '모텔')
# (451, '엔젤앤가든', 35.3248, 129.27, None, 1, '부산광역시', '기장군', '장안읍', '월내리', '산33-2', 'nan', 'nan', 403, 164, 364, 500, 430, 68, 451, 'Y', '펜션')
# (452, '길천여인숙', 35.3269, 129.284, None, 1, '부산광역시', '기장군', '장안읍', '길천리', '190', '길천길', '17380', 287, 449, 361, 347, 347, 54, 452, 'N', '모텔')
# (453, '늘봄펜션', 35.3472, 129.241, None, 1, '부산광역시', '기장군', '장안읍', '용소리', '395-3', '용소길', '103', 321, 126, 230, 437, 436, 50, 453, 'Y', '펜션')
# (454, '만석꾼캠핑장', 35.3311, 129.271, None, 1, '부산광역시', '기장군', '장안읍', '월내리', 'nan', '월내4길', '56-17', 159, 384, 375, 330, 179, 86, 454, 'Y', '모텔')
# (455, '월내태양민박', 35.3261, 129.277, None, 1, '부산광역시', '기장군', '장안읍', '월내리', '177-5', '월내해안2길', 'nan', 215, 84, 129, 229, 466, 432, 455, 'N', '모텔')
# (456, '달빛펜션', 35.3186, 129.263, None, 1, '부산광역시', '기장군', '장안읍', '임랑리', '19419', '임랑2길', '29', 306, 235, 297, 487, 481, 47, 456, 'Y', '펜션')
# (457, '아름민박집', 35.3182, 129.263, None, 1, '부산광역시', '기장군', '장안읍', '임랑리', '19450', '임랑2길', '27', 394, 132, 165, 402, 500, 458, 457, 'N', '모텔')
# (458, '해변민박', 35.3178, 129.263, None, 1, '부산광역시', '기장군', '장안읍', '임랑리', '20515', '임랑2길', '19', 180, 70, 87, 318, 452, 354, 458, 'N', '모텔')
# (459, '임랑별장민박', 35.3171, 129.263, None, 1, '부산광역시', '기장군', '장안읍', '임랑리', '146-1', '임랑2길', '14', 297, 33, 201, 304, 380, 364, 459, 'Y', '모텔')
# (460, '성남편의점민박', 35.3206, 129.266, None, 1, '부산광역시', '기장군', '장안읍', '임랑리', 'nan', '임랑해안길', '77', 70, 42, 67, 183, 438, 299, 460, 'N', '모텔')
# (461, '선민박', 35.3182, 129.264, None, 1, '부산광역시', '기장군', '장안읍', '임랑리', 'nan', '임랑해안길', '45', 213, 87, 146, 337, 485, 479, 461, 'N', '모텔')
# (462, '한바다민박', 35.3179, 129.263, None, 1, '부산광역시', '기장군', '장안읍', '임랑리', '1-72', '임랑해안길', '37', 276, 128, 180, 333, 471, 439, 462, 'N', '모텔')
# (463, '임랑펜션형브이민박', 35.3204, 129.266, None, 1, '부산광역시', '기장군', '장안읍', '임랑리', '1-32', '임랑해안길', '26665', 237, 132, 194, 423, 313, 47, 463, 'N', '펜션')
# (464, '더뷰펜션', 35.3167, 129.263, None, 1, '부산광역시', '기장군', '장안읍', '임랑리', '143', '임랑해안길', '23', 255, 137, 246, 324, 262, 30, 464, 'N', '펜션')
# (465, '양지민박', 35.319, 129.264, None, 1, '부산광역시', '기장군', '장안읍', '임랑리', '1-54', '임랑해안길', '18050', 239, 31, 63, 356, 499, 401, 465, 'N', '모텔')
# (466, '임랑태양민박', 35.3176, 129.263, None, 1, '부산광역시', '기장군', '장안읍', '임랑리', '140-1', '임랑해안길', '31', 179, 152, 167, 227, 360, 358, 466, 'N', '모텔')
# (467, '동부산온천호텔', 35.3434, 129.253, None, 1, '부산광역시', '기장군', '장안읍', '기룡리', '454-3', '장안로', '38', 39, 126, 117, 191, 66, 36, 467, 'Y', '호텔')
# (468, '산장가든', 35.3684, 129.247, None, 1, '부산광역시', '기장군', '장안읍', '장안리', '391-1', '장안로', '334', 103, 463, 425, 157, 128, 76, 468, 'Y', '모텔')
# (469, '장안사민박형펜션', 35.3485, 129.254, None, 1, '부산광역시', '기장군', '장안읍', '기룡리', '498-1', '장안로', '98', 316, 186, 295, 483, 408, 64, 469, 'N', '펜션')
# (470, '한옥펜션금수동', 35.3447, 129.253, None, 1, '부산광역시', '기장군', '장안읍', '기룡리', '468', '장안로', '18172', 218, 112, 190, 444, 366, 34, 470, 'Y', '펜션')
# (471, '장원민박', 35.3482, 129.254, None, 1, '부산광역시', '기장군', '장안읍', '기룡리', '294-1', '장안로', '94', 238, 134, 154, 274, 461, 388, 471, 'N', '모텔')
# (472, '장안캠프', 35.3422, 129.252, None, 1, '부산광역시', '기장군', '장안읍', '기룡리', '448', '장안로', '18', 285, 490, 363, 335, 291, 221, 472, 'N', '모텔')
# (473, '동부산온천호텔', 35.3433, 129.253, None, 1, '부산광역시', '기장군', '장안읍', '기룡리', '454-3', '장안로', '38', 95, 303, 227, 443, 128, 35, 473, 'Y', '호텔')
# (474, '루나펜션', 35.3636, 129.25, None, 1, '부산광역시', '기장군', '장안읍', '장안리', '106-1', '하장안1길', 'nan', 285, 180, 205, 365, 302, 38, 474, 'Y', '펜션')
# (475, '엔젤앤가든', 35.325, 129.271, None, 1, '부산광역시', '기장군', '장안읍', '월내리', '425-29', '해맞이로', '315-59', 284, 68, 102, 492, 450, 42, 475, 'N', '펜션')
# (476, '해파랑민박', 35.321, 129.267, None, 1, '부산광역시', '기장군', '장안읍', '임랑리', 'nan', '해맞이로', '250-22', 227, 68, 97, 263, 475, 358, 476, 'N', '모텔')
# (477, '보리수펜션', 35.3251, 129.271, None, 1, '부산광역시', '기장군', '장안읍', '월내리', '425-28', '해맞이로', '315-61', 255, 82, 215, 431, 360, 70, 477, 'Y', '펜션')
# (478, '오투펜션', 35.3219, 129.268, None, 1, '부산광역시', '기장군', '장안읍', '월내리', '554-4', '해맞이로', '272', 256, 189, 253, 439, 355, 91, 478, 'Y', '펜션')
# (479, '얀카라반펜션', 35.3216, 129.267, None, 1, '부산광역시', '기장군', '장안읍', '월내리', '554-23', '해맞이로', '250-64', 306, 30, 61, 334, 328, 30, 479, 'Y', '펜션')
# (480, '기장문화예절학교', 35.3255, 129.268, None, 1, '부산광역시', '기장군', '장안읍', '월내리', '579', '해맞이로', '311-31', 64, 353, 323, 245, 170, 34, 480, 'Y', '모텔')
# (481, '호수아펜션민박', 35.3214, 129.267, None, 1, '부산광역시', '기장군', '장안읍', '임랑리', 'nan', '해맞이로', '250-17', 306, 83, 219, 482, 328, 64, 481, 'N', '펜션')
# (482, '휴펜션', 35.3706, 129.244, None, 1, '부산광역시', '기장군', '장안읍', '장안리', '489', '협동로', '8', 315, 42, 130, 495, 478, 37, 482, 'N', '펜션')
# (483, '호텔다온', 35.3212, 129.18, None, 1, '부산광역시', '기장군', '정관읍', '매학리', '750-5', '구연4로', '12', 79, 207, 188, 395, 150, 55, 483, 'Y', '호텔')
# (484, '큐브모텔', 35.3212, 129.18, None, 1, '부산광역시', '기장군', '정관읍', '매학리', '750-5', '구연4로', '12', 94, 476, 465, 397, 235, 39, 484, 'Y', '모텔')
# (485, '파크모텔', 35.3218, 129.18, None, 1, '부산광역시', '기장군', '정관읍', '매학리', '750-1', '구연4로', '20', 151, 361, 306, 264, 216, 42, 485, 'Y', '모텔')
# (486, '기장군청소년수련관', 35.3111, 129.2, None, 1, '부산광역시', '기장군', '정관읍', '달산리', '417-22', '달음산길', '106', 63, 337, 159, 109, 92, 39, 486, 'Y', '모텔')
# (487, '병산골목장캠핑', 35.3453, 129.188, None, 1, '부산광역시', '기장군', '정관읍', '병산리', '567-3', '병산1길', '18', 285, 488, 430, 393, 317, 116, 487, 'N', '모텔')
# (488, '초원숲속야영장', 35.3451, 129.188, None, 1, '부산광역시', '기장군', '정관읍', '병산리', '567-3', '병산1길', '18', 315, 406, 369, 359, 350, 168, 488, 'N', '모텔')
# (489, 'k2모텔', 35.3161, 129.182, None, 1, '부산광역시', '기장군', '정관읍', '달산리', '1049-6', '산단1로', '98-41', 183, 486, 407, 386, 250, 178, 489, 'Y', '모텔')
# (490, '브라운도트호텔', 35.3161, 129.182, None, 1, '부산광역시', '기장군', '정관읍', '달산리', '1049-5', '산단1로', '98-31', 137, 340, 330, 494, 231, 121, 490, 'Y', '호텔')
# (491, '호텔라움', 35.3161, 129.181, None, 1, '부산광역시', '기장군', '정관읍', '달산리', '1049-3', '산단1로', '98-17', 142, 328, 179, 385, 173, 65, 491, 'Y', '호텔')
# (492, '호텔썸', 35.3161, 129.181, None, 1, '부산광역시', '기장군', '정관읍', '달산리', '1049-4', '산단1로', '98-25', 176, 371, 291, 434, 281, 60, 492, 'Y', '호텔')
# (493, '더원호텔', 35.3164, 129.184, None, 1, '부산광역시', '기장군', '정관읍', '달산리', '1049-13', '산단2로', '11414', 203, 463, 418, 476, 343, 116, 493, 'Y', '호텔')
# (494, '호텔여기어때', 35.3162, 129.183, None, 1, '부산광역시', '기장군', '정관읍', '달산리', '1049-9', '산단2로', '31-32', 150, 345, 258, 476, 209, 131, 494, 'Y', '호텔')
# (495, '실베네집', 35.2362, 129.177, None, 1, '부산광역시', '기장군', '철마면', '안평리', '223-13', '안평로33번길', '11', 266, 55, 167, 295, 460, 399, 495, 'Y', '모텔')
# (496, '영남장여관', 35.1185, 129.079, None, 1, '부산광역시', '남구', '감만동', 'nan', '85-61', '8부두로', '9', 81, 498, 474, 374, 288, 46, 496, 'Y', '모텔')
# (497, '신라장여관', 35.1164, 129.081, None, 1, '부산광역시', '남구', '감만동', 'nan', '163-17', '우암로', '24108', 318, 485, 404, 398, 377, 184, 497, 'N', '모텔')
# (498, '새여관', 35.1179, 129.08, None, 1, '부산광역시', '남구', '감만동', 'nan', '88-15', '우암로79번길', '17', 116, 493, 460, 442, 436, 97, 498, 'N', '모텔')
# (499, '리베모텔', 35.1357, 129.092, None, 1, '부산광역시', '남구', '대연동', 'nan', '1741-14', '못골로', '90', 151, 470, 301, 298, 229, 74, 499, 'Y', '모텔')
# (500, '남일여인숙', 35.1356, 129.092, None, 1, '부산광역시', '남구', '대연동', 'nan', '1741-21', '못골로', '33604', 141, 452, 373, 293, 287, 101, 500, 'N', '모텔')
# ...
# (2583, '타이완마미하우스', 35.1783, 129.175, None, 1, '부산광역시', '해운대구', '좌동', 'nan', '1396', '대천로103번길', '47', 73, 402, 220, 53, 45, 73, 2583, 'N', '게스트하우스')
# (2584, '온앤온하우스', 35.1794, 129.179, None, 1, '부산광역시', '해운대구', '좌동', 'nan', '1413', '세실로', '174', 39, 454, 257, 52, 33, 97, 2584, 'N', '게스트하우스')
# (2585, '해운대JOO하우스', 35.1707, 129.166, None, 1, '부산광역시', '해운대구', '좌동', 'nan', '1341-19', '좌동순환로', '47', 34, 440, 392, 96, 39, 40, 2585, 'N', '게스트하우스')
# (2586, '해운대몽돌하우스', 35.1766, 129.167, None, 1, '부산광역시', '해운대구', '좌동', 'nan', '1375', '좌동순환로99번길', '22', 99, 476, 214, 60, 59, 99, 2586, 'N', '게스트하우스')
# (2587, '호텔안', 35.1692, 129.177, None, 1, '부산광역시', '해운대구', '좌동', 'nan', '1479-1', '해운대로', '802', 182, 295, 218, 392, 213, 69, 2587, 'N', '호텔')
# (2588, 'IN351게스트하우스', 35.1641, 129.168, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1269-9', 'nan', 'nan', 99, 355, 299, 43, 38, 87, 2588, 'N', '게스트하우스')
# (2589, '프리호텔', 35.1638, 129.175, None, 1, '부산광역시', '해운대구', '중동', 'nan', '726-6', 'nan', 'nan', 220, 432, 380, 480, 344, 71, 2589, 'N', '호텔')
# (2590, '바다풍경펜션', 35.1615, 129.162, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1393-78', '구남로', '35-13', 208, 119, 166, 495, 484, 111, 2590, 'Y', '펜션')
# (2591, '바다풍경펜션', 35.1615, 129.162, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1393-78', '구남로', '35-13', 398, 281, 388, 444, 420, 226, 2591, 'Y', '펜션')
# (2592, '라비드아틀란호텔', 35.1611, 129.161, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1392-166', '구남로', '37', 136, 393, 226, 418, 199, 99, 2592, 'Y', '호텔')
# (2593, '엘리시아부티크호텔', 35.1602, 129.162, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1392-26', '구남로', '49', 269, 434, 364, 466, 361, 176, 2593, 'N', '호텔')
# (2594, '베스트웨스턴 해운대호텔', 35.1604, 129.161, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1391-42', '구남로', '42', 79, 412, 246, 478, 211, 72, 2594, 'Y', '호텔')
# (2595, '선셋비즈니스호텔', 35.1601, 129.161, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1391-66', '구남로', '46', 60, 368, 210, 399, 165, 36, 2595, 'Y', '호텔')
# (2596, '라메르펜션', 35.1601, 129.162, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1392-26', '구남로', '49', 295, 110, 154, 431, 407, 69, 2596, 'N', '펜션')
# (2597, '리베로호텔', 35.1622, 129.161, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1380-14', '구남로29번길', '21', 234, 372, 321, 433, 297, 169, 2597, 'Y', '호텔')
# (2598, '파라디아모텔', 35.1621, 129.162, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1382-23', '구남로29번길', 'nan', 76, 390, 272, 260, 109, 70, 2598, 'Y', '모텔')
# (2599, '팍스게스트하우스', 35.1624, 129.162, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1380-26', '구남로29번길', '32', 97, 413, 286, 79, 56, 31, 2599, 'N', '게스트하우스')
# (2600, '예그린민박', 35.1607, 129.162, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1394-120', '구남로41번길', 'nan', 238, 33, 172, 307, 481, 311, 2600, 'Y', '모텔')
# (2601, '찬게스트하우스', 35.1615, 129.162, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1394-95', '구남로41번길', 'nan', 74, 222, 262, 76, 100, 46, 2601, 'N', '게스트하우스')
# (2602, '해운대바다민박', 35.1606, 129.162, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1394-119', '구남로41번길', 'nan', 236, 68, 133, 243, 332, 311, 2602, 'N', '모텔')
# (2603, '도담게스트하우스', 35.1618, 129.162, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1394-247', '구남로41번길', 'nan', 79, 403, 421, 86, 95, 77, 2603, 'N', '게스트하우스')
# (2604, '더베이게스트하우스', 35.1615, 129.162, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1394-245', '구남로41번길', 'nan', 96, 424, 395, 50, 91, 39, 2604, 'N', '게스트하우스')
# (2605, '킹콩게스트하우스', 35.1621, 129.163, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1394-2', '구남로41번길', '46', 50, 464, 491, 46, 65, 74, 2605, 'N', '게스트하우스')
# (2606, '엘시티레지던스', 35.1604, 129.169, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1829', '달맞이길', '30', 83, 371, 329, 397, 115, 64, 2606, 'Y', '호텔')
# (2607, '그랜드엘시티레지던스', 35.16, 129.17, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1829', '달맞이길', '30', 57, 392, 211, 452, 103, 46, 2607, 'Y', '호텔')
# (2608, '시그니엘 부산', 35.1599, 129.17, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1829', '달맞이길', '30', 129, 415, 358, 473, 323, 66, 2608, 'Y', '호텔')
# (2609, '송도각모텔', 35.1617, 129.166, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1126-21', '달맞이길', '10', 184, 488, 443, 424, 409, 71, 2609, 'Y', '모텔')
# (2610, '폴에이리조트해운대', 35.1623, 129.167, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1150-1', '달맞이길', '13', 72, 348, 188, 397, 137, 40, 2610, 'Y', '호텔')
# (2611, 'Y게스트하우스', 35.1619, 129.165, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1152-5', '달맞이길', 'nan', 98, 363, 261, 78, 69, 48, 2611, 'N', '게스트하우스')
# (2612, '엘솔게스트하우스', 35.162, 129.167, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1147-12', '달맞이길', '20', 92, 279, 305, 92, 50, 52, 2612, 'N', '게스트하우스')
# (2613, '마야게스트하우스', 35.1616, 129.166, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1126-18', '달맞이길', 'nan', 47, 450, 279, 57, 63, 96, 2613, 'N', '게스트하우스')
# (2614, '썬앤문게스트하우스', 35.1583, 129.182, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1489-4', '달맞이길', '193', 44, 459, 256, 34, 52, 90, 2614, 'N', '게스트하우스')
# (2615, '해운온천대중탕모텔', 35.1619, 129.166, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1128-41', '달맞이길', '8', 141, 454, 415, 412, 191, 59, 2615, 'Y', '모텔')
# (2616, '선트리호텔', 35.1595, 129.183, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1488-7', '달맞이길', '209', 178, 328, 301, 486, 242, 119, 2616, 'Y', '호텔')
# (2617, '일루아호텔', 35.1589, 129.175, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1509-3', '달맞이길', '97', 156, 445, 243, 474, 215, 123, 2617, 'Y', '호텔')
# (2618, 'W모텔', 35.1592, 129.183, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1488-11', '달맞이길117번가길', '174', 93, 443, 373, 350, 292, 58, 2618, 'N', '모텔')
# (2619, '칸게스트하우스', 35.1603, 129.183, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1481-9', '달맞이길117번가길', '200', 86, 480, 340, 36, 45, 81, 2619, 'N', '게스트하우스')
# (2620, '해운대오피스텔민박', 35.1593, 129.175, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1510-17', '달맞이길117번길', '17-30', 209, 74, 169, 414, 494, 466, 2620, 'Y', '모텔')
# (2621, '물고기나무펜션', 35.1583, 129.172, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1021-3', '달맞이길62번가길', '43', 323, 244, 305, 428, 341, 121, 2621, 'N', '펜션')
# (2622, '비치하우스', 35.1588, 129.171, None, 1, '부산광역시', '해운대구', '중동', 'nan', '963', '달맞이길62번가길', '25', 63, 243, 468, 37, 87, 80, 2622, 'N', '게스트하우스')
# (2623, '삼삼오오펜션', 35.1586, 129.172, None, 1, '부산광역시', '해운대구', '중동', 'nan', '964', '달맞이길62번가길', '31', 403, 250, 325, 493, 405, 191, 2623, 'Y', '펜션')
# (2624, '삼삼오오펜션', 35.1587, 129.172, None, 1, '부산광역시', '해운대구', '중동', 'nan', '965-3', '달맞이길62번가길', '31', 223, 197, 216, 438, 396, 179, 2624, 'Y', '펜션')
# (2625, '휘겔리 호텔', 35.1584, 129.172, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1026', '달맞이길62번가길', '37', 192, 445, 433, 470, 343, 141, 2625, 'Y', '호텔')
# (2626, '삼삼오오펜션', 35.1587, 129.172, None, 1, '부산광역시', '해운대구', '중동', 'nan', '964', '달맞이길62번가길', '31', 328, 298, 315, 492, 344, 38, 2626, 'Y', '펜션')
# (2627, '대구장여관', 35.1583, 129.172, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1017-1', '달맞이길62번가길', '43', 53, 302, 272, 195, 145, 32, 2627, 'Y', '모텔')
# (2628, '전망좋은모텔', 35.1593, 129.17, None, 1, '부산광역시', '해운대구', '중동', 'nan', '957-9', '달맞이길62번길', '23', 39, 451, 403, 287, 274, 38, 2628, 'Y', '모텔')
# (2629, '미포오션사이드호텔', 35.1589, 129.171, None, 1, '부산광역시', '해운대구', '중동', 'nan', '957-1', '달맞이길62번길', '28', 216, 435, 355, 447, 343, 212, 2629, 'Y', '호텔')
# (2630, '게스트하우스레움', 35.1575, 129.173, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1009-11', '달맞이길62번길', '55', 42, 450, 229, 40, 91, 74, 2630, 'N', '게스트하우스')
# (2631, '해운대썬블루비치펜션', 35.1608, 129.171, None, 1, '부산광역시', '해운대구', '중동', 'nan', '940-3', '달맞이길62번길', '3', 395, 242, 247, 487, 412, 91, 2631, 'Y', '펜션')
# (2632, '미포유게스트하우스', 35.1603, 129.171, None, 1, '부산광역시', '해운대구', '중동', 'nan', '946-1', '달맞이길62번길', 'nan', 90, 346, 210, 48, 99, 39, 2632, 'N', '게스트하우스')
# (2633, '포도펜션', 35.1569, 129.174, None, 1, '부산광역시', '해운대구', '중동', 'nan', '996-6', '달맞이길62번길', '67', 233, 77, 97, 389, 256, 33, 2633, 'N', '펜션')
# (2634, '해운대비치모텔', 35.1576, 129.173, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1010', '달맞이길62번길', '53', 205, 500, 471, 373, 206, 147, 2634, 'Y', '모텔')
# (2635, '시원게스트하우스', 35.1618, 129.175, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1521-30', '좌동순환로', '415', 78, 450, 316, 34, 99, 41, 2635, 'N', '게스트하우스')
# (2636, '마마게스트하우스', 35.162, 129.163, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1394-228', '중동1로', '40', 94, 347, 450, 60, 55, 53, 2636, 'N', '게스트하우스')
# (2637, '24게스트하우스', 35.1631, 129.162, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1394-18', '중동1로', 'nan', 75, 427, 223, 46, 91, 68, 2637, 'N', '게스트하우스')
# (2638, '골든베이풀빌라펜션', 35.1612, 129.163, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1394-344', '중동1로', '42-22', 322, 105, 114, 473, 454, 92, 2638, 'N', '펜션')
# (2639, '해운대펜트하우스', 35.1635, 129.162, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1394-15', '중동1로', '17', 57, 396, 401, 57, 92, 60, 2639, 'N', '게스트하우스')
# (2640, '멜론게스트하우스', 35.1618, 129.164, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1394-337', '중동1로', '45', 65, 335, 383, 42, 97, 80, 2640, 'N', '게스트하우스')
# (2641, '문탠모텔', 35.1617, 129.163, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1394-350', '중동1로', '16103', 194, 480, 467, 424, 278, 65, 2641, 'Y', '모텔')
# (2642, '24게스트하우스', 35.1632, 129.162, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1394-37', '중동1로', '22', 33, 283, 251, 86, 72, 55, 2642, 'N', '게스트하우스')
# (2643, '해운대소라텔하우스', 35.1617, 129.163, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1394-361', '중동1로', '15676', 40, 479, 260, 68, 47, 47, 2643, 'N', '게스트하우스')
# (2644, '가든모텔', 35.1616, 129.163, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1394-343', '중동1로', '42-14', 278, 491, 442, 428, 280, 163, 2644, 'Y', '모텔')
# (2645, '해운대민박', 35.1619, 129.163, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1394-313', '중동1로', '15493', 447, 70, 172, 476, 499, 476, 2645, 'N', '모텔')
# (2646, '해운대온천호텔', 35.1615, 129.163, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1394-352', '중동1로', '46', 273, 337, 295, 348, 288, 83, 2646, 'N', '호텔')
# (2647, '백팩커스하우스', 35.1619, 129.163, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1394-313', '중동1로', '15493', 78, 391, 434, 84, 30, 85, 2647, 'N', '게스트하우스')
# (2648, '타임게스트하우스', 35.1636, 129.162, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1379-9', '중동1로19번길', '5', 34, 314, 208, 40, 45, 89, 2648, 'N', '게스트하우스')
# (2649, '뷰티크팰리스호텔', 35.1634, 129.163, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1378-56', '중동1로19번길', '16', 66, 399, 220, 432, 88, 39, 2649, 'N', '호텔')
# (2650, '오륙도여관', 35.1623, 129.164, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1394-215', '중동1로37번길', 'nan', 68, 163, 149, 102, 90, 45, 2650, 'N', '모텔')
# (2651, '파도소리모텔', 35.1622, 129.164, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1394-329', '중동1로43번길', '11', 272, 495, 438, 349, 332, 117, 2651, 'N', '모텔')
# (2652, '매직모텔', 35.1622, 129.164, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1394-330', '중동1로43번길', '13', 171, 359, 246, 237, 212, 46, 2652, 'Y', '모텔')
# (2653, '블루피쉬게스트하우스', 35.1619, 129.164, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1394-338', '중동1로43번길', '10', 82, 408, 251, 33, 33, 58, 2653, 'N', '게스트하우스')
# (2654, '맘게스트하우스', 35.1628, 129.165, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1372-12', '중동2로', '8', 30, 304, 458, 44, 46, 46, 2654, 'N', '게스트하우스')
# (2655, '청사포펜션', 35.1622, 129.194, None, 1, '부산광역시', '해운대구', '중동', 'nan', '520-1', '청사포로', '153', 263, 143, 181, 474, 438, 141, 2655, 'Y', '펜션')
# (2656, '블루비치호텔', 35.1602, 129.191, None, 1, '부산광역시', '해운대구', '중동', 'nan', '598', '청사포로128번길', '40', 305, 403, 366, 437, 315, 223, 2656, 'N', '호텔')
# (2657, '호텔카멜리아', 35.1598, 129.161, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1417-2', '해운대해변로', '271', 211, 382, 262, 473, 233, 99, 2657, 'N', '호텔')
# (2658, '그랜드조선', 35.16, 129.163, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1405-16', '해운대해변로', '292', 200, 338, 248, 373, 221, 162, 2658, 'Y', '호텔')
# (2659, '피앤에스호텔', 35.1621, 129.165, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1398-16', '해운대해변로', '315', 103, 378, 341, 383, 210, 70, 2659, 'Y', '호텔')
# (2660, 'UH Suite Landscape 4F', 35.1598, 129.161, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1417-2', '해운대해변로', '271', 230, 418, 296, 428, 241, 181, 2660, 'Y', '호텔')
# (2661, '썬클라우드호텔', 35.1604, 129.162, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1392-100', '해운대해변로', '287', 277, 453, 421, 476, 352, 73, 2661, 'Y', '호텔')
# (2662, '페어필드바이메리어트부산호텔', 35.1616, 129.165, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1400-60', '해운대해변로', '314', 140, 262, 187, 474, 149, 109, 2662, 'Y', '호텔')
# (2663, '경원장여관', 35.1627, 129.165, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1373-24', '해운대해변로', '329-12', 155, 444, 414, 170, 162, 47, 2663, 'N', '모텔')
# (2664, '뉴비치호텔', 35.1599, 129.162, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1412-7', '해운대해변로', '277', 61, 355, 104, 439, 72, 49, 2664, 'N', '호텔')
# (2665, 'MS호텔', 35.1598, 129.161, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1417-2', '해운대해변로', '271', 184, 341, 288, 361, 284, 140, 2665, 'Y', '호텔')
# (2666, 'UH Suite The Haeundae', 35.1598, 129.161, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1417-2', '해운대해변로', '271', 197, 308, 277, 481, 234, 165, 2666, 'Y', '호텔')
# (2667, '하야리게스트하우스', 35.1607, 129.162, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1394-286', '해운대해변로', '291', 93, 345, 458, 98, 31, 81, 2667, 'N', '게스트하우스')
# (2668, '위드게스트하우스', 35.1625, 129.165, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1398-7', '해운대해변로', '321', 49, 259, 426, 90, 61, 73, 2668, 'N', '게스트하우스')
# (2669, '베니키아호텔해운대', 35.1623, 129.165, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1398-23', '해운대해변로', '317', 89, 235, 206, 468, 155, 66, 2669, 'Y', '호텔')
# (2670, '누리호텔', 35.1598, 129.161, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1417-2', '해운대해변로', '271', 50, 142, 127, 344, 84, 46, 2670, 'N', '호텔')
# (2671, '마리안느호텔', 35.1615, 129.165, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1400-24', '해운대해변로', '310', 151, 417, 399, 498, 337, 92, 2671, 'Y', '호텔')
# (2672, '레지던스 더 문', 35.1625, 129.165, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1398-7', '해운대해변로', '321', 337, 467, 435, 483, 359, 191, 2672, 'N', '호텔')
# (2673, '석원장', 35.1632, 129.167, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1223-1', '해운대해변로', '337', 129, 456, 288, 176, 131, 64, 2673, 'Y', '모텔')
# (2674, '금호장', 35.1631, 129.166, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1373-29', '해운대해변로', '331', 62, 345, 337, 251, 63, 61, 2674, 'Y', '모텔')
# (2675, '파라다이스호텔', 35.1602, 129.165, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1411-1', '해운대해변로', '296', 124, 392, 291, 436, 260, 106, 2675, 'Y', '호텔')
# (2676, '코오롱 씨클라우드 호텔', 35.1604, 129.162, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1392-100', '해운대해변로', '287', 350, 453, 420, 497, 403, 35, 2676, 'Y', '호텔')
# (2677, '청풍장온천여관', 35.1626, 129.166, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1154-4', '해운대해변로', '332', 115, 351, 322, 295, 227, 47, 2677, 'Y', '모텔')
# (2678, '골든튤립해운대호텔&스위트', 35.1623, 129.166, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1153-8', '해운대해변로', '322', 100, 458, 223, 477, 170, 88, 2678, 'Y', '호텔')
# (2679, '토요코인호텔 해운대2', 35.1595, 129.157, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1130-1', '해운대해변로237번길', '5', 178, 436, 374, 482, 210, 43, 2679, 'Y', '호텔')
# (2680, '팔레드시즈', 35.1602, 129.167, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1124-2', '해운대해변로298번길', '24', 64, 400, 357, 477, 139, 39, 2680, 'Y', '호텔')
# (2681, '해운대영무파라드호텔', 35.1609, 129.167, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1124-8', '해운대해변로298번길', '25', 245, 445, 434, 494, 393, 43, 2681, 'N', '호텔')
# (2682, '칠공하우스', 35.1602, 129.167, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1124-2', '해운대해변로298번길', '24', 40, 403, 418, 91, 58, 49, 2682, 'Y', '게스트하우스')
# (2683, '골든리스트', 35.1602, 129.167, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1124-2', '해운대해변로298번길', '24', 94, 478, 287, 486, 165, 66, 2683, 'Y', '호텔')
# (2684, '호텔 더 마크 해운대', 35.161, 129.167, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1123', '해운대해변로298번길', '29', 128, 366, 270, 434, 267, 77, 2684, 'Y', '호텔')
# (2685, '해운대센트럴호텔', 35.161, 129.167, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1137-4', '해운대해변로298번길', '33', 218, 354, 321, 467, 317, 49, 2685, 'Y', '호텔')
# (2686, '해운대 영무파라드호텔', 35.1609, 129.166, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1124-8', '해운대해변로298번길', '25', 215, 347, 346, 349, 307, 77, 2686, 'Y', '호텔')
# (2687, '해운대센트럴호텔', 35.1609, 129.167, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1137-4', '해운대해변로298번길', '33', 52, 252, 248, 430, 143, 39, 2687, 'N', '호텔')
# (2688, '호텔벨리아', 35.1613, 129.167, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1123', '해운대해변로298번길', '29', 130, 251, 203, 416, 198, 76, 2688, 'N', '호텔')
# (2689, '해운대네이티브게스트하우스', 35.1645, 129.168, None, 1, '부산광역시', '해운대구', '중동', 'nan', '1267-22', '해운대해변로351번길', 'nan', 67, 301, 284, 35, 46, 36, 2689, 'N', '게스트하우스')

# %%
cur.close()
conn.close()
